# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import nltk
import sys
import os

# Download required NLTK resources 
nltk.download(['punkt','punkt_tab','wordnet'], quiet=True)
#nltk.download('omw-1.4')
#nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.multioutput import MultiOutputClassifier
import pickle

import warnings
import logging

# Suppress warnings
warnings.filterwarnings('ignore')

# Suppress logging
logging.getLogger().setLevel(logging.ERROR)

# %%
def load_data(database_filepath=None):
    """
    Load data from SQLite database
    
    Parameters:
    database_filepath (str, optional): Path to SQLite database
    
    Returns:
    X (pandas.Series): Feature data (messages)
    Y (pandas.DataFrame): Target data (categories)
    category_names (list): List of category names
    """
    # Get the current working directory
    current_dir = os.getcwd()
    
    # If no filepath provided, use default location
    if database_filepath is None:
        # Navigate up one directory to project root, then into data folder
        database_filepath = os.path.join(current_dir, '..', 'data', 'DisasterResponse.db')
    else:
        # If a relative path is provided, construct full path
        database_filepath = os.path.join(current_dir, '..', database_filepath)
    
    # Load data from database
    engine = create_engine(f'sqlite:///{database_filepath}')
    df = pd.read_sql_table('DisasterResponse', engine)
    
    # Define features and target
    X = df['message']
    Y = df.iloc[:, 4:]  # All columns from the 5th column onwards
    category_names = Y.columns
    
    return X, Y, category_names

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    """
    Process text data: tokenize, lemmatize, and clean
    
    Parameters:
    text (str): Text to be processed
    
    Returns:
    clean_tokens (list): List of cleaned tokens
    """
    # Replace URLs with a placeholder
    url_regex = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")
    
    # Tokenize, lemmatize, and clean
    tokens = word_tokenize(text.lower())
    lemmatizer = WordNetLemmatizer()
    
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).strip()
        clean_tokens.append(clean_tok)
    
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
def build_model():
    """
    Build a machine learning pipeline with GridSearchCV
    
    Returns:
    cv (GridSearchCV): GridSearchCV object with pipeline and parameter grid
    """
    # Create pipeline
    pipeline = Pipeline([
        ('cvect', CountVectorizer(tokenizer=tokenize, token_pattern=None)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier(n_estimators=100, random_state=42)))
    ])
    
    # Define parameters for GridSearchCV
    parameters = {
        'cvect__max_features': [100, 200],
        'cvect__ngram_range': [(1, 1), (1, 2)],
        'tfidf__use_idf': [True, False],
        'clf__estimator__n_estimators': [50, 100]
    }
    
    # Create GridSearchCV object
    #cv = GridSearchCV(pipeline, param_grid=parameters, cv=3, verbose=2, n_jobs=-1)
    cv = GridSearchCV(pipeline, param_grid=parameters, cv=3, verbose=0, n_jobs=-1)
    
    return cv

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# Define the database filepath
database_filepath = 'data/DisasterResponse.db'

# Then call load_data
X, Y, category_names = load_data(database_filepath)
# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
        
#Build model
model = build_model()
        
#train model
model.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('cvect',
#                                         CountVectorizer(token_pattern=None,
#                                                         tokenizer=<function tokenize at 0x151440860>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier(random_state=42)))]),
#              n_jobs=-1,
#              param_grid={'clf__estimator__n_estimators': [50, 100],
#                          'cvect__max_features': [100, 200],
#                          'cvect__ngram_range': [(1, 1), (1, 2)],
#                          'tfidf__use_idf': [True, False]})

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# Make predictions
Y_pred = model.predict(X_test)

# %%
def evaluate_model(Y_test, Y_pred, category_names):
    # Check dimensions of y_pred
    if len(Y_pred.shape) == 1:
        # If y_pred is 1D but y_test has multiple columns
        if len(category_names) > 1:
            print("Warning: y_pred is 1-dimensional but multiple categories were provided.")
            print("Make sure your model is properly configured for multi-label classification.")
            
        # For 1D predictions, we can only evaluate one category
        category = category_names[0]
        Y_true = Y_test.iloc[:, 0]
        Y_pred_cat = Y_pred
        
        report = classification_report(Y_true, Ypred_cat, output_dict=True, zero_division=0)
        df_report = pd.DataFrame(report).round(2)
        
        print(f'\n{"="*50}')
        print(f'Category: {category}')
        print(f'{"="*50}')
        
        # Style with colorblind-friendly colors
        styled_df = df_report.style\
            .background_gradient(cmap='YlOrBr')\
            .format(precision=2)\
            .set_table_styles([
                {'selector': 'th', 'props': [('background-color', '#eee'),
                                          ('color', '#000'),
                                          ('font-weight', 'bold')]},
                {'selector': '', 'props': [('border', '2px solid #333')]},
                {'selector': 'tbody td', 'props': [('border', '1px solid #666')]}
            ])\
            .highlight_max(axis=1, color='#8cc2dd')\
            .highlight_min(axis=1, color='#ffe5cc')
        
        display(styled_df)
    else:
        # Original multi-category evaluation
        for idx, category in enumerate(category_names):
            Y_true = Y_test.iloc[:, idx]
            # IMPORTANT FIX: Don't reuse the y_pred variable name inside the loop
            Y_pred_cat = Y_pred[:, idx]
            
            report = classification_report(Y_true, Y_pred_cat, output_dict=True, zero_division=0)
            df_report = pd.DataFrame(report).round(2)
            
            print(f'\n{"="*50}')
            print(f'Category: {category}')
            print(f'{"="*50}')
            
            # Style with colorblind-friendly colors
            styled_df = df_report.style\
                .background_gradient(cmap='YlOrBr')\
                .format(precision=2)\
                .set_table_styles([
                    {'selector': 'th', 'props': [('background-color', '#eee'),
                                              ('color', '#000'),
                                              ('font-weight', 'bold')]},
                    {'selector': '', 'props': [('border', '2px solid #333')]},
                    {'selector': 'tbody td', 'props': [('border', '1px solid #666')]}
                ])\
                .highlight_max(axis=1, color='#8cc2dd')\
                .highlight_min(axis=1, color='#ffe5cc')
            
            display(styled_df)

# %%
def predict_message(message, categories):
    """
    Predict categories for a single message
    
    Parameters:
    message (str): The input message to classify
    categories (list): List of category names
    
    Returns:
    dict: Predicted categories with value 1
    """
    # Predict categories for a single message
    prediction = model.predict([message])[0]
    
    # Create a dictionary of categories and their predictions
    results = dict(zip(categories, prediction))
    
    # Return only categories with prediction of 1
    return {category: result for category, result in results.items() if result == 1}

# When calling the function, pass the category_names
sample_message = "There's a flood in Houston, Texas. We need water and medical supplies."
predictions = predict_message(sample_message, category_names)
print("\nSample Message Predictions:")
print("Message:", sample_message)
print("Predictions:", predictions)
# Out:
# Sample Message Predictions:
# Message: There's a flood in Houston, Texas. We need water and medical supplies.
# Predictions: {'related': np.int64(1), 'request': np.int64(1), 'aid_related': np.int64(1), 'medical_help': np.int64(1), 'medical_products': np.int64(1), 'water': np.int64(1), 'weather_related': np.int64(1), 'floods': np.int64(1), 'direct_report': np.int64(1)}

# %%
Y_pred[111].shape
# Out:
# (36,)

# %%
for i in range(36):
    print("=======================",Y_test.columns[i],"======================")
    print(classification_report(Y_test.iloc[:,i], Y_pred[:,i], zero_division=0))
# Out:
# ======================= related ======================
#               precision    recall  f1-score   support
#
#            0       0.65      0.31      0.43      1245
#            1       0.82      0.95      0.88      3998
#
#     accuracy                           0.80      5243
#    macro avg       0.74      0.63      0.65      5243
# weighted avg       0.78      0.80      0.77      5243
#
# ======================= request ======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4352
#            1       0.84      0.50      0.62       891
#
#     accuracy                           0.90      5243
#    macro avg       0.87      0.74      0.78      5243
# weighted avg       0.89      0.90      0.89      5243
#
# ======================= offer ======================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        24
#
#     accuracy                           1.00      5243
#    macro avg       0.50      0.50      0.50      5243
# weighted avg       0.99      1.00      0.99      5243
#
# ======================= aid_related ======================
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79      3079
#            1       0.73      0.58      0.65      2164
#
#     accuracy                           0.74      5243
#    macro avg       0.74      0.72      0.72      5243
# weighted avg       0.74      0.74      0.73      5243
#
# ======================= medical_help ======================
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4808
#            1       0.58      0.07      0.13       435
#
#     accuracy                           0.92      5243
#    macro avg       0.75      0.53      0.54      5243
# weighted avg       0.89      0.92      0.89      5243
#
# ======================= medical_products ======================
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4964
#            1       0.53      0.04      0.07       279
#
#     accuracy                           0.95      5243
#    macro avg       0.74      0.52      0.52      5243
# weighted avg       0.93      0.95      0.92      5243
#
# ======================= search_and_rescue ======================
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5107
#            1       0.00      0.00      0.00       136
#
#     accuracy                           0.97      5243
#    macro avg       0.49      0.50      0.49      5243
# weighted avg       0.95      0.97      0.96      5243
#
# ======================= security ======================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5147
#            1       1.00      0.01      0.02        96
#
#     accuracy                           0.98      5243
#    macro avg       0.99      0.51      0.51      5243
# weighted avg       0.98      0.98      0.97      5243
#
# ======================= military ======================
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5085
#            1       0.00      0.00      0.00       158
#
#     accuracy                           0.97      5243
#    macro avg       0.48      0.50      0.49      5243
# weighted avg       0.94      0.97      0.95      5243
#
# ======================= child_alone ======================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5243
#
#     accuracy                           1.00      5243
#    macro avg       1.00      1.00      1.00      5243
# weighted avg       1.00      1.00      1.00      5243
#
# ======================= water ======================
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4908
#            1       0.88      0.45      0.60       335
#
#     accuracy                           0.96      5243
#    macro avg       0.92      0.72      0.79      5243
# weighted avg       0.96      0.96      0.96      5243
#
# ======================= food ======================
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4659
#            1       0.83      0.66      0.73       584
#
#     accuracy                           0.95      5243
#    macro avg       0.90      0.82      0.85      5243
# weighted avg       0.94      0.95      0.94      5243
#
# ======================= shelter ======================
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4775
#            1       0.82      0.49      0.61       468
#
#     accuracy                           0.94      5243
#    macro avg       0.89      0.74      0.79      5243
# weighted avg       0.94      0.94      0.94      5243
#
# ======================= clothing ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5173
#            1       0.00      0.00      0.00        70
#
#     accuracy                           0.99      5243
#    macro avg       0.49      0.50      0.50      5243
# weighted avg       0.97      0.99      0.98      5243
#
# ======================= money ======================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5131
#            1       0.83      0.04      0.08       112
#
#     accuracy                           0.98      5243
#    macro avg       0.91      0.52      0.54      5243
# weighted avg       0.98      0.98      0.97      5243
#
# ======================= missing_people ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5180
#            1       0.00      0.00      0.00        63
#
#     accuracy                           0.99      5243
#    macro avg       0.49      0.50      0.50      5243
# weighted avg       0.98      0.99      0.98      5243
#
# ======================= refugees ======================
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5073
#            1       0.00      0.00      0.00       170
#
#     accuracy                           0.97      5243
#    macro avg       0.48      0.50      0.49      5243
# weighted avg       0.94      0.97      0.95      5243
#
# ======================= death ======================
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4996
#            1       0.78      0.03      0.05       247
#
#     accuracy                           0.95      5243
#    macro avg       0.87      0.51      0.52      5243
# weighted avg       0.95      0.95      0.93      5243
#
# ======================= other_aid ======================
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      4551
#            1       0.64      0.08      0.14       692
#
#     accuracy                           0.87      5243
#    macro avg       0.76      0.54      0.54      5243
# weighted avg       0.84      0.87      0.83      5243
#
# ======================= infrastructure_related ======================
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4907
#            1       0.75      0.01      0.02       336
#
#     accuracy                           0.94      5243
#    macro avg       0.84      0.50      0.49      5243
# weighted avg       0.92      0.94      0.91      5243
#
# ======================= transport ======================
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5008
#            1       0.66      0.12      0.21       235
#
#     accuracy                           0.96      5243
#    macro avg       0.81      0.56      0.59      5243
# weighted avg       0.95      0.96      0.94      5243
#
# ======================= buildings ======================
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4974
#            1       0.75      0.16      0.26       269
#
#     accuracy                           0.95      5243
#    macro avg       0.86      0.58      0.62      5243
# weighted avg       0.95      0.95      0.94      5243
#
# ======================= electricity ======================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5128
#            1       1.00      0.03      0.07       115
#
#     accuracy                           0.98      5243
#    macro avg       0.99      0.52      0.53      5243
# weighted avg       0.98      0.98      0.97      5243
#
# ======================= tools ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5208
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.99      5243
#    macro avg       0.50      0.50      0.50      5243
# weighted avg       0.99      0.99      0.99      5243
#
# ======================= hospitals ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5191
#            1       0.00      0.00      0.00        52
#
#     accuracy                           0.99      5243
#    macro avg       0.50      0.50      0.50      5243
# weighted avg       0.98      0.99      0.99      5243
#
# ======================= shops ======================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5218
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      5243
#    macro avg       0.50      0.50      0.50      5243
# weighted avg       0.99      1.00      0.99      5243
#
# ======================= aid_centers ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5179
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.99      5243
#    macro avg       0.49      0.50      0.50      5243
# weighted avg       0.98      0.99      0.98      5243
#
# ======================= other_infrastructure ======================
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5018
#            1       0.00      0.00      0.00       225
#
#     accuracy                           0.96      5243
#    macro avg       0.48      0.50      0.49      5243
# weighted avg       0.92      0.96      0.94      5243
#
# ======================= weather_related ======================
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      3771
#            1       0.84      0.56      0.67      1472
#
#     accuracy                           0.84      5243
#    macro avg       0.84      0.76      0.78      5243
# weighted avg       0.84      0.84      0.83      5243
#
# ======================= floods ======================
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4812
#            1       0.91      0.36      0.51       431
#
#     accuracy                           0.94      5243
#    macro avg       0.93      0.68      0.74      5243
# weighted avg       0.94      0.94      0.93      5243
#
# ======================= storm ======================
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      4764
#            1       0.74      0.52      0.61       479
#
#     accuracy                           0.94      5243
#    macro avg       0.85      0.75      0.79      5243
# weighted avg       0.93      0.94      0.93      5243
#
# ======================= fire ======================
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5190
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.99      5243
#    macro avg       0.49      0.50      0.50      5243
# weighted avg       0.98      0.99      0.98      5243
#
# ======================= earthquake ======================
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      4728
#            1       0.90      0.67      0.77       515
#
#     accuracy                           0.96      5243
#    macro avg       0.93      0.83      0.87      5243
# weighted avg       0.96      0.96      0.96      5243
#
# ======================= cold ======================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5139
#            1       0.00      0.00      0.00       104
#
#     accuracy                           0.98      5243
#    macro avg       0.49      0.50      0.49      5243
# weighted avg       0.96      0.98      0.97      5243
#
# ======================= other_weather ======================
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4976
#            1       0.33      0.01      0.01       267
#
#     accuracy                           0.95      5243
#    macro avg       0.64      0.50      0.49      5243
# weighted avg       0.92      0.95      0.92      5243
#
# ======================= direct_report ======================
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      4233
#            1       0.80      0.42      0.55      1010
#
#     accuracy                           0.87      5243
#    macro avg       0.84      0.70      0.73      5243
# weighted avg       0.86      0.87      0.85      5243

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
# Parameter grid with exactly 4 combinations (2×2=4)
parameters = {
    'cvect__max_features': [100, 50],
    'cvect__ngram_range': [(1, 1), (1, 2)]
}

# Keep all other parameters fixed
pipeline = Pipeline([
    ('cvect', CountVectorizer(tokenizer=tokenize, token_pattern=None)),
    ('tfidf', TfidfTransformer(use_idf=True)),  # Fixed value
    ('clf', MultiOutputClassifier(RandomForestClassifier(n_estimators=100, min_samples_split=2)))  # Fixed values
])

# %%
# This will result in 4 combinations × 5 folds = 20 fits
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_pipeline = GridSearchCV(pipeline, param_grid=parameters, cv=5, n_jobs=-1, verbose=2)
    cv_pipeline.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
# Print the best parameters found
print("Best parameters:", cv_pipeline.best_params_)

# Evaluate on test set
Y_pred = cv_pipeline.predict(X_test)
print("\nModel Performance with best parameters:")
evaluate_model(Y_test, Y_pred, category_names)
# Out:
# Best parameters: {'cvect__max_features': 100, 'cvect__ngram_range': (1, 1)}
#
# Model Performance with best parameters:
#
# ==================================================
# Category: related
# ==================================================
# <style type="text/css">
# #T_b0d31 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_b0d31  {
#   border: 2px solid #333;
# }
# #T_b0d31 tbody td {
#   border: 1px solid #666;
# }
# #T_b0d31_row0_col0, #T_b0d31_row1_col0, #T_b0d31_row2_col0, #T_b0d31_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_b0d31_row0_col1, #T_b0d31_row1_col1, #T_b0d31_row2_col1 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_b0d31_row0_col2, #T_b0d31_row0_col3, #T_b0d31_row0_col4, #T_b0d31_row1_col2, #T_b0d31_row1_col3, #T_b0d31_row1_col4, #T_b0d31_row2_col2, #T_b0d31_row2_col3, #T_b0d31_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_b0d31_row3_col0, #T_b0d31_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_b0d31_row3_col3, #T_b0d31_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_b0d31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0d31_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b0d31_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b0d31_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_b0d31_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_b0d31_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0d31_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_b0d31_row0_col0" class="data row0 col0" >0.63</td>
#       <td id="T_b0d31_row0_col1" class="data row0 col1" >0.81</td>
#       <td id="T_b0d31_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_b0d31_row0_col3" class="data row0 col3" >0.72</td>
#       <td id="T_b0d31_row0_col4" class="data row0 col4" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_b0d31_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_b0d31_row1_col0" class="data row1 col0" >0.29</td>
#       <td id="T_b0d31_row1_col1" class="data row1 col1" >0.95</td>
#       <td id="T_b0d31_row1_col2" class="data row1 col2" >0.79</td>
#       <td id="T_b0d31_row1_col3" class="data row1 col3" >0.62</td>
#       <td id="T_b0d31_row1_col4" class="data row1 col4" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_b0d31_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_b0d31_row2_col0" class="data row2 col0" >0.40</td>
#       <td id="T_b0d31_row2_col1" class="data row2 col1" >0.87</td>
#       <td id="T_b0d31_row2_col2" class="data row2 col2" >0.79</td>
#       <td id="T_b0d31_row2_col3" class="data row2 col3" >0.64</td>
#       <td id="T_b0d31_row2_col4" class="data row2 col4" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_b0d31_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_b0d31_row3_col0" class="data row3 col0" >1245.00</td>
#       <td id="T_b0d31_row3_col1" class="data row3 col1" >3998.00</td>
#       <td id="T_b0d31_row3_col2" class="data row3 col2" >0.79</td>
#       <td id="T_b0d31_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_b0d31_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: request
# ==================================================
# <style type="text/css">
# #T_ee8a2 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_ee8a2  {
#   border: 2px solid #333;
# }
# #T_ee8a2 tbody td {
#   border: 1px solid #666;
# }
# #T_ee8a2_row0_col0, #T_ee8a2_row1_col0, #T_ee8a2_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_ee8a2_row0_col1, #T_ee8a2_row1_col1, #T_ee8a2_row2_col1, #T_ee8a2_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_ee8a2_row0_col2, #T_ee8a2_row0_col3, #T_ee8a2_row0_col4, #T_ee8a2_row1_col2, #T_ee8a2_row1_col3, #T_ee8a2_row1_col4, #T_ee8a2_row2_col2, #T_ee8a2_row2_col3, #T_ee8a2_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_ee8a2_row3_col0, #T_ee8a2_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_ee8a2_row3_col3, #T_ee8a2_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_ee8a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee8a2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ee8a2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ee8a2_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_ee8a2_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_ee8a2_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee8a2_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_ee8a2_row0_col0" class="data row0 col0" >0.91</td>
#       <td id="T_ee8a2_row0_col1" class="data row0 col1" >0.81</td>
#       <td id="T_ee8a2_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_ee8a2_row0_col3" class="data row0 col3" >0.86</td>
#       <td id="T_ee8a2_row0_col4" class="data row0 col4" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_ee8a2_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_ee8a2_row1_col0" class="data row1 col0" >0.98</td>
#       <td id="T_ee8a2_row1_col1" class="data row1 col1" >0.50</td>
#       <td id="T_ee8a2_row1_col2" class="data row1 col2" >0.90</td>
#       <td id="T_ee8a2_row1_col3" class="data row1 col3" >0.74</td>
#       <td id="T_ee8a2_row1_col4" class="data row1 col4" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_ee8a2_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_ee8a2_row2_col0" class="data row2 col0" >0.94</td>
#       <td id="T_ee8a2_row2_col1" class="data row2 col1" >0.62</td>
#       <td id="T_ee8a2_row2_col2" class="data row2 col2" >0.90</td>
#       <td id="T_ee8a2_row2_col3" class="data row2 col3" >0.78</td>
#       <td id="T_ee8a2_row2_col4" class="data row2 col4" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_ee8a2_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_ee8a2_row3_col0" class="data row3 col0" >4352.00</td>
#       <td id="T_ee8a2_row3_col1" class="data row3 col1" >891.00</td>
#       <td id="T_ee8a2_row3_col2" class="data row3 col2" >0.90</td>
#       <td id="T_ee8a2_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_ee8a2_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: offer
# ==================================================
# <style type="text/css">
# #T_4f9d2 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_4f9d2  {
#   border: 2px solid #333;
# }
# #T_4f9d2 tbody td {
#   border: 1px solid #666;
# }
# #T_4f9d2_row0_col0, #T_4f9d2_row0_col2, #T_4f9d2_row1_col0, #T_4f9d2_row1_col2, #T_4f9d2_row1_col4, #T_4f9d2_row2_col0, #T_4f9d2_row2_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_4f9d2_row0_col1, #T_4f9d2_row1_col1, #T_4f9d2_row2_col1, #T_4f9d2_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_4f9d2_row0_col3, #T_4f9d2_row0_col4, #T_4f9d2_row1_col3, #T_4f9d2_row2_col3, #T_4f9d2_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4f9d2_row3_col0, #T_4f9d2_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_4f9d2_row3_col3, #T_4f9d2_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_4f9d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f9d2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4f9d2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4f9d2_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_4f9d2_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_4f9d2_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f9d2_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_4f9d2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_4f9d2_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_4f9d2_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_4f9d2_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_4f9d2_row0_col4" class="data row0 col4" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_4f9d2_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_4f9d2_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_4f9d2_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_4f9d2_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_4f9d2_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_4f9d2_row1_col4" class="data row1 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_4f9d2_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_4f9d2_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_4f9d2_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_4f9d2_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_4f9d2_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_4f9d2_row2_col4" class="data row2 col4" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_4f9d2_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_4f9d2_row3_col0" class="data row3 col0" >5219.00</td>
#       <td id="T_4f9d2_row3_col1" class="data row3 col1" >24.00</td>
#       <td id="T_4f9d2_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_4f9d2_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_4f9d2_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: aid_related
# ==================================================
# <style type="text/css">
# #T_d9647 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_d9647  {
#   border: 2px solid #333;
# }
# #T_d9647 tbody td {
#   border: 1px solid #666;
# }
# #T_d9647_row0_col0, #T_d9647_row0_col2, #T_d9647_row1_col0, #T_d9647_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_d9647_row0_col1, #T_d9647_row1_col1, #T_d9647_row2_col1, #T_d9647_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_d9647_row0_col3, #T_d9647_row0_col4, #T_d9647_row1_col2, #T_d9647_row1_col3, #T_d9647_row1_col4, #T_d9647_row2_col2, #T_d9647_row2_col3, #T_d9647_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_d9647_row3_col0, #T_d9647_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_d9647_row3_col3, #T_d9647_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_d9647">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9647_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d9647_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d9647_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_d9647_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_d9647_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9647_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_d9647_row0_col0" class="data row0 col0" >0.73</td>
#       <td id="T_d9647_row0_col1" class="data row0 col1" >0.71</td>
#       <td id="T_d9647_row0_col2" class="data row0 col2" >0.73</td>
#       <td id="T_d9647_row0_col3" class="data row0 col3" >0.72</td>
#       <td id="T_d9647_row0_col4" class="data row0 col4" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_d9647_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_d9647_row1_col0" class="data row1 col0" >0.84</td>
#       <td id="T_d9647_row1_col1" class="data row1 col1" >0.56</td>
#       <td id="T_d9647_row1_col2" class="data row1 col2" >0.73</td>
#       <td id="T_d9647_row1_col3" class="data row1 col3" >0.70</td>
#       <td id="T_d9647_row1_col4" class="data row1 col4" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_d9647_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_d9647_row2_col0" class="data row2 col0" >0.78</td>
#       <td id="T_d9647_row2_col1" class="data row2 col1" >0.63</td>
#       <td id="T_d9647_row2_col2" class="data row2 col2" >0.73</td>
#       <td id="T_d9647_row2_col3" class="data row2 col3" >0.70</td>
#       <td id="T_d9647_row2_col4" class="data row2 col4" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_d9647_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_d9647_row3_col0" class="data row3 col0" >3079.00</td>
#       <td id="T_d9647_row3_col1" class="data row3 col1" >2164.00</td>
#       <td id="T_d9647_row3_col2" class="data row3 col2" >0.73</td>
#       <td id="T_d9647_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_d9647_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: medical_help
# ==================================================
# <style type="text/css">
# #T_64857 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_64857  {
#   border: 2px solid #333;
# }
# #T_64857 tbody td {
#   border: 1px solid #666;
# }
# #T_64857_row0_col0, #T_64857_row0_col2, #T_64857_row1_col0, #T_64857_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_64857_row0_col1, #T_64857_row1_col1, #T_64857_row2_col1, #T_64857_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_64857_row0_col3, #T_64857_row0_col4, #T_64857_row1_col2, #T_64857_row1_col3, #T_64857_row1_col4, #T_64857_row2_col2, #T_64857_row2_col3, #T_64857_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_64857_row3_col0, #T_64857_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_64857_row3_col3, #T_64857_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_64857">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64857_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_64857_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_64857_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_64857_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_64857_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64857_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_64857_row0_col0" class="data row0 col0" >0.92</td>
#       <td id="T_64857_row0_col1" class="data row0 col1" >0.42</td>
#       <td id="T_64857_row0_col2" class="data row0 col2" >0.92</td>
#       <td id="T_64857_row0_col3" class="data row0 col3" >0.67</td>
#       <td id="T_64857_row0_col4" class="data row0 col4" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_64857_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_64857_row1_col1" class="data row1 col1" >0.01</td>
#       <td id="T_64857_row1_col2" class="data row1 col2" >0.92</td>
#       <td id="T_64857_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_64857_row1_col4" class="data row1 col4" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_64857_row2_col0" class="data row2 col0" >0.96</td>
#       <td id="T_64857_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_64857_row2_col2" class="data row2 col2" >0.92</td>
#       <td id="T_64857_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_64857_row2_col4" class="data row2 col4" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_64857_row3_col0" class="data row3 col0" >4808.00</td>
#       <td id="T_64857_row3_col1" class="data row3 col1" >435.00</td>
#       <td id="T_64857_row3_col2" class="data row3 col2" >0.92</td>
#       <td id="T_64857_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_64857_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: medical_products
# ==================================================
# <style type="text/css">
# #T_5a9cb th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_5a9cb  {
#   border: 2px solid #333;
# }
# #T_5a9cb tbody td {
#   border: 1px solid #666;
# }
# #T_5a9cb_row0_col0, #T_5a9cb_row0_col2, #T_5a9cb_row1_col0, #T_5a9cb_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_5a9cb_row0_col1, #T_5a9cb_row1_col1, #T_5a9cb_row2_col1, #T_5a9cb_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_5a9cb_row0_col3, #T_5a9cb_row0_col4, #T_5a9cb_row1_col2, #T_5a9cb_row1_col3, #T_5a9cb_row1_col4, #T_5a9cb_row2_col2, #T_5a9cb_row2_col3, #T_5a9cb_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5a9cb_row3_col0, #T_5a9cb_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_5a9cb_row3_col3, #T_5a9cb_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_5a9cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a9cb_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5a9cb_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5a9cb_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_5a9cb_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_5a9cb_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a9cb_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_5a9cb_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_5a9cb_row0_col1" class="data row0 col1" >0.60</td>
#       <td id="T_5a9cb_row0_col2" class="data row0 col2" >0.95</td>
#       <td id="T_5a9cb_row0_col3" class="data row0 col3" >0.77</td>
#       <td id="T_5a9cb_row0_col4" class="data row0 col4" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5a9cb_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_5a9cb_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_5a9cb_row1_col1" class="data row1 col1" >0.02</td>
#       <td id="T_5a9cb_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_5a9cb_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_5a9cb_row1_col4" class="data row1 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_5a9cb_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_5a9cb_row2_col0" class="data row2 col0" >0.97</td>
#       <td id="T_5a9cb_row2_col1" class="data row2 col1" >0.04</td>
#       <td id="T_5a9cb_row2_col2" class="data row2 col2" >0.95</td>
#       <td id="T_5a9cb_row2_col3" class="data row2 col3" >0.51</td>
#       <td id="T_5a9cb_row2_col4" class="data row2 col4" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_5a9cb_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_5a9cb_row3_col0" class="data row3 col0" >4964.00</td>
#       <td id="T_5a9cb_row3_col1" class="data row3 col1" >279.00</td>
#       <td id="T_5a9cb_row3_col2" class="data row3 col2" >0.95</td>
#       <td id="T_5a9cb_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_5a9cb_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: search_and_rescue
# ==================================================
# <style type="text/css">
# #T_79388 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_79388  {
#   border: 2px solid #333;
# }
# #T_79388 tbody td {
#   border: 1px solid #666;
# }
# #T_79388_row0_col0, #T_79388_row0_col2, #T_79388_row1_col0, #T_79388_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_79388_row0_col1, #T_79388_row1_col1, #T_79388_row2_col1, #T_79388_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_79388_row0_col3, #T_79388_row0_col4, #T_79388_row1_col2, #T_79388_row1_col3, #T_79388_row1_col4, #T_79388_row2_col2, #T_79388_row2_col3, #T_79388_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_79388_row3_col0, #T_79388_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_79388_row3_col3, #T_79388_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_79388">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79388_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_79388_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_79388_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_79388_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_79388_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79388_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_79388_row0_col0" class="data row0 col0" >0.97</td>
#       <td id="T_79388_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_79388_row0_col2" class="data row0 col2" >0.97</td>
#       <td id="T_79388_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_79388_row0_col4" class="data row0 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_79388_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_79388_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_79388_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_79388_row1_col2" class="data row1 col2" >0.97</td>
#       <td id="T_79388_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_79388_row1_col4" class="data row1 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_79388_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_79388_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_79388_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_79388_row2_col2" class="data row2 col2" >0.97</td>
#       <td id="T_79388_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_79388_row2_col4" class="data row2 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_79388_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_79388_row3_col0" class="data row3 col0" >5107.00</td>
#       <td id="T_79388_row3_col1" class="data row3 col1" >136.00</td>
#       <td id="T_79388_row3_col2" class="data row3 col2" >0.97</td>
#       <td id="T_79388_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_79388_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: security
# ==================================================
# <style type="text/css">
# #T_a00e2 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_a00e2  {
#   border: 2px solid #333;
# }
# #T_a00e2 tbody td {
#   border: 1px solid #666;
# }
# #T_a00e2_row0_col0, #T_a00e2_row0_col2, #T_a00e2_row1_col0, #T_a00e2_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_a00e2_row0_col1 {
#   background-color: #ffffe4;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_a00e2_row0_col3, #T_a00e2_row0_col4, #T_a00e2_row1_col2, #T_a00e2_row1_col3, #T_a00e2_row1_col4, #T_a00e2_row2_col2, #T_a00e2_row2_col3, #T_a00e2_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a00e2_row1_col1, #T_a00e2_row2_col1, #T_a00e2_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_a00e2_row3_col0, #T_a00e2_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_a00e2_row3_col3, #T_a00e2_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_a00e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a00e2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a00e2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a00e2_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_a00e2_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_a00e2_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a00e2_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_a00e2_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_a00e2_row0_col1" class="data row0 col1" >0.50</td>
#       <td id="T_a00e2_row0_col2" class="data row0 col2" >0.98</td>
#       <td id="T_a00e2_row0_col3" class="data row0 col3" >0.74</td>
#       <td id="T_a00e2_row0_col4" class="data row0 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_a00e2_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_a00e2_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_a00e2_row1_col1" class="data row1 col1" >0.01</td>
#       <td id="T_a00e2_row1_col2" class="data row1 col2" >0.98</td>
#       <td id="T_a00e2_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_a00e2_row1_col4" class="data row1 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_a00e2_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_a00e2_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_a00e2_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_a00e2_row2_col2" class="data row2 col2" >0.98</td>
#       <td id="T_a00e2_row2_col3" class="data row2 col3" >0.51</td>
#       <td id="T_a00e2_row2_col4" class="data row2 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_a00e2_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_a00e2_row3_col0" class="data row3 col0" >5147.00</td>
#       <td id="T_a00e2_row3_col1" class="data row3 col1" >96.00</td>
#       <td id="T_a00e2_row3_col2" class="data row3 col2" >0.98</td>
#       <td id="T_a00e2_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_a00e2_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: military
# ==================================================
# <style type="text/css">
# #T_5741f th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_5741f  {
#   border: 2px solid #333;
# }
# #T_5741f tbody td {
#   border: 1px solid #666;
# }
# #T_5741f_row0_col0, #T_5741f_row0_col2, #T_5741f_row1_col0, #T_5741f_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_5741f_row0_col1, #T_5741f_row1_col1, #T_5741f_row2_col1, #T_5741f_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_5741f_row0_col3, #T_5741f_row0_col4, #T_5741f_row1_col2, #T_5741f_row1_col3, #T_5741f_row1_col4, #T_5741f_row2_col2, #T_5741f_row2_col3, #T_5741f_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5741f_row3_col0, #T_5741f_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_5741f_row3_col3, #T_5741f_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_5741f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5741f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5741f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5741f_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_5741f_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_5741f_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5741f_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_5741f_row0_col0" class="data row0 col0" >0.97</td>
#       <td id="T_5741f_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_5741f_row0_col2" class="data row0 col2" >0.97</td>
#       <td id="T_5741f_row0_col3" class="data row0 col3" >0.48</td>
#       <td id="T_5741f_row0_col4" class="data row0 col4" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_5741f_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_5741f_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_5741f_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_5741f_row1_col2" class="data row1 col2" >0.97</td>
#       <td id="T_5741f_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_5741f_row1_col4" class="data row1 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_5741f_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_5741f_row2_col0" class="data row2 col0" >0.98</td>
#       <td id="T_5741f_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_5741f_row2_col2" class="data row2 col2" >0.97</td>
#       <td id="T_5741f_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_5741f_row2_col4" class="data row2 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_5741f_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_5741f_row3_col0" class="data row3 col0" >5085.00</td>
#       <td id="T_5741f_row3_col1" class="data row3 col1" >158.00</td>
#       <td id="T_5741f_row3_col2" class="data row3 col2" >0.97</td>
#       <td id="T_5741f_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_5741f_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: child_alone
# ==================================================
# <style type="text/css">
# #T_75c21 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_75c21  {
#   border: 2px solid #333;
# }
# #T_75c21 tbody td {
#   border: 1px solid #666;
# }
# #T_75c21_row0_col0, #T_75c21_row0_col1, #T_75c21_row0_col2, #T_75c21_row0_col3, #T_75c21_row1_col0, #T_75c21_row1_col1, #T_75c21_row1_col2, #T_75c21_row1_col3, #T_75c21_row2_col0, #T_75c21_row2_col1, #T_75c21_row2_col2, #T_75c21_row2_col3 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
#   background-color: #ffe5cc;
# }
# #T_75c21_row3_col0, #T_75c21_row3_col2, #T_75c21_row3_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# #T_75c21_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# </style>
# <table id="T_75c21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c21_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_75c21_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_75c21_level0_col2" class="col_heading level0 col2" >macro avg</th>
#       <th id="T_75c21_level0_col3" class="col_heading level0 col3" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75c21_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_75c21_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_75c21_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_75c21_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_75c21_row0_col3" class="data row0 col3" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_75c21_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_75c21_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_75c21_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_75c21_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_75c21_row1_col3" class="data row1 col3" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_75c21_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_75c21_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_75c21_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_75c21_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_75c21_row2_col3" class="data row2 col3" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_75c21_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_75c21_row3_col0" class="data row3 col0" >5243.00</td>
#       <td id="T_75c21_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_75c21_row3_col2" class="data row3 col2" >5243.00</td>
#       <td id="T_75c21_row3_col3" class="data row3 col3" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: water
# ==================================================
# <style type="text/css">
# #T_e39cf th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_e39cf  {
#   border: 2px solid #333;
# }
# #T_e39cf tbody td {
#   border: 1px solid #666;
# }
# #T_e39cf_row0_col0, #T_e39cf_row0_col2, #T_e39cf_row0_col4, #T_e39cf_row1_col0, #T_e39cf_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_e39cf_row0_col1, #T_e39cf_row1_col1, #T_e39cf_row2_col1, #T_e39cf_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_e39cf_row0_col3, #T_e39cf_row1_col2, #T_e39cf_row1_col3, #T_e39cf_row1_col4, #T_e39cf_row2_col2, #T_e39cf_row2_col3, #T_e39cf_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e39cf_row3_col0, #T_e39cf_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_e39cf_row3_col3, #T_e39cf_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_e39cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e39cf_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e39cf_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e39cf_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_e39cf_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_e39cf_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e39cf_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_e39cf_row0_col0" class="data row0 col0" >0.96</td>
#       <td id="T_e39cf_row0_col1" class="data row0 col1" >0.81</td>
#       <td id="T_e39cf_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_e39cf_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_e39cf_row0_col4" class="data row0 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e39cf_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_e39cf_row1_col0" class="data row1 col0" >0.99</td>
#       <td id="T_e39cf_row1_col1" class="data row1 col1" >0.47</td>
#       <td id="T_e39cf_row1_col2" class="data row1 col2" >0.96</td>
#       <td id="T_e39cf_row1_col3" class="data row1 col3" >0.73</td>
#       <td id="T_e39cf_row1_col4" class="data row1 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e39cf_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_e39cf_row2_col0" class="data row2 col0" >0.98</td>
#       <td id="T_e39cf_row2_col1" class="data row2 col1" >0.60</td>
#       <td id="T_e39cf_row2_col2" class="data row2 col2" >0.96</td>
#       <td id="T_e39cf_row2_col3" class="data row2 col3" >0.79</td>
#       <td id="T_e39cf_row2_col4" class="data row2 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_e39cf_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_e39cf_row3_col0" class="data row3 col0" >4908.00</td>
#       <td id="T_e39cf_row3_col1" class="data row3 col1" >335.00</td>
#       <td id="T_e39cf_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_e39cf_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_e39cf_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: food
# ==================================================
# <style type="text/css">
# #T_20500 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_20500  {
#   border: 2px solid #333;
# }
# #T_20500 tbody td {
#   border: 1px solid #666;
# }
# #T_20500_row0_col0, #T_20500_row1_col0, #T_20500_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_20500_row0_col1, #T_20500_row1_col1, #T_20500_row2_col1, #T_20500_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_20500_row0_col2, #T_20500_row0_col3, #T_20500_row0_col4, #T_20500_row1_col2, #T_20500_row1_col3, #T_20500_row1_col4, #T_20500_row2_col2, #T_20500_row2_col3, #T_20500_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_20500_row3_col0, #T_20500_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_20500_row3_col3, #T_20500_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_20500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20500_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_20500_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_20500_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_20500_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_20500_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20500_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_20500_row0_col0" class="data row0 col0" >0.96</td>
#       <td id="T_20500_row0_col1" class="data row0 col1" >0.83</td>
#       <td id="T_20500_row0_col2" class="data row0 col2" >0.95</td>
#       <td id="T_20500_row0_col3" class="data row0 col3" >0.90</td>
#       <td id="T_20500_row0_col4" class="data row0 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_20500_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_20500_row1_col0" class="data row1 col0" >0.98</td>
#       <td id="T_20500_row1_col1" class="data row1 col1" >0.68</td>
#       <td id="T_20500_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_20500_row1_col3" class="data row1 col3" >0.83</td>
#       <td id="T_20500_row1_col4" class="data row1 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_20500_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_20500_row2_col0" class="data row2 col0" >0.97</td>
#       <td id="T_20500_row2_col1" class="data row2 col1" >0.75</td>
#       <td id="T_20500_row2_col2" class="data row2 col2" >0.95</td>
#       <td id="T_20500_row2_col3" class="data row2 col3" >0.86</td>
#       <td id="T_20500_row2_col4" class="data row2 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_20500_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_20500_row3_col0" class="data row3 col0" >4659.00</td>
#       <td id="T_20500_row3_col1" class="data row3 col1" >584.00</td>
#       <td id="T_20500_row3_col2" class="data row3 col2" >0.95</td>
#       <td id="T_20500_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_20500_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: shelter
# ==================================================
# <style type="text/css">
# #T_9c497 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_9c497  {
#   border: 2px solid #333;
# }
# #T_9c497 tbody td {
#   border: 1px solid #666;
# }
# #T_9c497_row0_col0, #T_9c497_row0_col2, #T_9c497_row1_col0, #T_9c497_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_9c497_row0_col1, #T_9c497_row1_col1, #T_9c497_row2_col1, #T_9c497_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_9c497_row0_col3, #T_9c497_row0_col4, #T_9c497_row1_col2, #T_9c497_row1_col3, #T_9c497_row1_col4, #T_9c497_row2_col2, #T_9c497_row2_col3, #T_9c497_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_9c497_row3_col0, #T_9c497_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_9c497_row3_col3, #T_9c497_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_9c497">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c497_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9c497_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9c497_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_9c497_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_9c497_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c497_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_9c497_row0_col0" class="data row0 col0" >0.94</td>
#       <td id="T_9c497_row0_col1" class="data row0 col1" >0.83</td>
#       <td id="T_9c497_row0_col2" class="data row0 col2" >0.94</td>
#       <td id="T_9c497_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_9c497_row0_col4" class="data row0 col4" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_9c497_row1_col0" class="data row1 col0" >0.99</td>
#       <td id="T_9c497_row1_col1" class="data row1 col1" >0.36</td>
#       <td id="T_9c497_row1_col2" class="data row1 col2" >0.94</td>
#       <td id="T_9c497_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_9c497_row1_col4" class="data row1 col4" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_9c497_row2_col0" class="data row2 col0" >0.97</td>
#       <td id="T_9c497_row2_col1" class="data row2 col1" >0.50</td>
#       <td id="T_9c497_row2_col2" class="data row2 col2" >0.94</td>
#       <td id="T_9c497_row2_col3" class="data row2 col3" >0.73</td>
#       <td id="T_9c497_row2_col4" class="data row2 col4" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_9c497_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_9c497_row3_col0" class="data row3 col0" >4775.00</td>
#       <td id="T_9c497_row3_col1" class="data row3 col1" >468.00</td>
#       <td id="T_9c497_row3_col2" class="data row3 col2" >0.94</td>
#       <td id="T_9c497_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_9c497_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: clothing
# ==================================================
# <style type="text/css">
# #T_d0633 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_d0633  {
#   border: 2px solid #333;
# }
# #T_d0633 tbody td {
#   border: 1px solid #666;
# }
# #T_d0633_row0_col0, #T_d0633_row0_col2, #T_d0633_row1_col0, #T_d0633_row2_col0, #T_d0633_row2_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_d0633_row0_col1, #T_d0633_row1_col1, #T_d0633_row2_col1, #T_d0633_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_d0633_row0_col3, #T_d0633_row0_col4, #T_d0633_row1_col2, #T_d0633_row1_col3, #T_d0633_row1_col4, #T_d0633_row2_col3, #T_d0633_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_d0633_row3_col0, #T_d0633_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_d0633_row3_col3, #T_d0633_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_d0633">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0633_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d0633_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d0633_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_d0633_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_d0633_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0633_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_d0633_row0_col0" class="data row0 col0" >0.99</td>
#       <td id="T_d0633_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_d0633_row0_col2" class="data row0 col2" >0.99</td>
#       <td id="T_d0633_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_d0633_row0_col4" class="data row0 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_d0633_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_d0633_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_d0633_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_d0633_row1_col2" class="data row1 col2" >0.99</td>
#       <td id="T_d0633_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_d0633_row1_col4" class="data row1 col4" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_d0633_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_d0633_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_d0633_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_d0633_row2_col2" class="data row2 col2" >0.99</td>
#       <td id="T_d0633_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_d0633_row2_col4" class="data row2 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_d0633_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_d0633_row3_col0" class="data row3 col0" >5173.00</td>
#       <td id="T_d0633_row3_col1" class="data row3 col1" >70.00</td>
#       <td id="T_d0633_row3_col2" class="data row3 col2" >0.99</td>
#       <td id="T_d0633_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_d0633_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: money
# ==================================================
# <style type="text/css">
# #T_199f4 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_199f4  {
#   border: 2px solid #333;
# }
# #T_199f4 tbody td {
#   border: 1px solid #666;
# }
# #T_199f4_row0_col0, #T_199f4_row0_col2, #T_199f4_row1_col0, #T_199f4_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_199f4_row0_col1 {
#   background-color: #ffffe4;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_199f4_row0_col3, #T_199f4_row0_col4, #T_199f4_row1_col2, #T_199f4_row1_col3, #T_199f4_row1_col4, #T_199f4_row2_col2, #T_199f4_row2_col3, #T_199f4_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_199f4_row1_col1, #T_199f4_row2_col1, #T_199f4_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_199f4_row3_col0, #T_199f4_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_199f4_row3_col3, #T_199f4_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_199f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_199f4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_199f4_level0_col1" class="col_heading level0 col1" >1</th>
# ...
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f88b0_row3_col0, #T_f88b0_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_f88b0_row3_col3, #T_f88b0_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_f88b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f88b0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f88b0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f88b0_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_f88b0_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_f88b0_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f88b0_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_f88b0_row0_col0" class="data row0 col0" >0.99</td>
#       <td id="T_f88b0_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_f88b0_row0_col2" class="data row0 col2" >0.99</td>
#       <td id="T_f88b0_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_f88b0_row0_col4" class="data row0 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_f88b0_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_f88b0_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_f88b0_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_f88b0_row1_col2" class="data row1 col2" >0.99</td>
#       <td id="T_f88b0_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_f88b0_row1_col4" class="data row1 col4" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_f88b0_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_f88b0_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_f88b0_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_f88b0_row2_col2" class="data row2 col2" >0.99</td>
#       <td id="T_f88b0_row2_col3" class="data row2 col3" >0.50</td>
#       <td id="T_f88b0_row2_col4" class="data row2 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_f88b0_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_f88b0_row3_col0" class="data row3 col0" >5190.00</td>
#       <td id="T_f88b0_row3_col1" class="data row3 col1" >53.00</td>
#       <td id="T_f88b0_row3_col2" class="data row3 col2" >0.99</td>
#       <td id="T_f88b0_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_f88b0_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: earthquake
# ==================================================
# <style type="text/css">
# #T_1513e th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_1513e  {
#   border: 2px solid #333;
# }
# #T_1513e tbody td {
#   border: 1px solid #666;
# }
# #T_1513e_row0_col0, #T_1513e_row0_col2, #T_1513e_row0_col4, #T_1513e_row1_col0, #T_1513e_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_1513e_row0_col1, #T_1513e_row1_col1, #T_1513e_row2_col1, #T_1513e_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_1513e_row0_col3, #T_1513e_row1_col2, #T_1513e_row1_col3, #T_1513e_row1_col4, #T_1513e_row2_col2, #T_1513e_row2_col3, #T_1513e_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1513e_row3_col0, #T_1513e_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_1513e_row3_col3, #T_1513e_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_1513e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1513e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1513e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1513e_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_1513e_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_1513e_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1513e_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_1513e_row0_col0" class="data row0 col0" >0.96</td>
#       <td id="T_1513e_row0_col1" class="data row0 col1" >0.89</td>
#       <td id="T_1513e_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_1513e_row0_col3" class="data row0 col3" >0.93</td>
#       <td id="T_1513e_row0_col4" class="data row0 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_1513e_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_1513e_row1_col0" class="data row1 col0" >0.99</td>
#       <td id="T_1513e_row1_col1" class="data row1 col1" >0.67</td>
#       <td id="T_1513e_row1_col2" class="data row1 col2" >0.96</td>
#       <td id="T_1513e_row1_col3" class="data row1 col3" >0.83</td>
#       <td id="T_1513e_row1_col4" class="data row1 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_1513e_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_1513e_row2_col0" class="data row2 col0" >0.98</td>
#       <td id="T_1513e_row2_col1" class="data row2 col1" >0.76</td>
#       <td id="T_1513e_row2_col2" class="data row2 col2" >0.96</td>
#       <td id="T_1513e_row2_col3" class="data row2 col3" >0.87</td>
#       <td id="T_1513e_row2_col4" class="data row2 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_1513e_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_1513e_row3_col0" class="data row3 col0" >4728.00</td>
#       <td id="T_1513e_row3_col1" class="data row3 col1" >515.00</td>
#       <td id="T_1513e_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_1513e_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_1513e_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: cold
# ==================================================
# <style type="text/css">
# #T_e436f th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_e436f  {
#   border: 2px solid #333;
# }
# #T_e436f tbody td {
#   border: 1px solid #666;
# }
# #T_e436f_row0_col0, #T_e436f_row0_col2, #T_e436f_row1_col0, #T_e436f_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_e436f_row0_col1, #T_e436f_row1_col1, #T_e436f_row2_col1, #T_e436f_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_e436f_row0_col3, #T_e436f_row0_col4, #T_e436f_row1_col2, #T_e436f_row1_col3, #T_e436f_row1_col4, #T_e436f_row2_col2, #T_e436f_row2_col3, #T_e436f_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e436f_row3_col0, #T_e436f_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_e436f_row3_col3, #T_e436f_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_e436f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e436f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e436f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e436f_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_e436f_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_e436f_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e436f_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_e436f_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_e436f_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_e436f_row0_col2" class="data row0 col2" >0.98</td>
#       <td id="T_e436f_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_e436f_row0_col4" class="data row0 col4" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e436f_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_e436f_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_e436f_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_e436f_row1_col2" class="data row1 col2" >0.98</td>
#       <td id="T_e436f_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_e436f_row1_col4" class="data row1 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_e436f_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_e436f_row2_col0" class="data row2 col0" >0.99</td>
#       <td id="T_e436f_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_e436f_row2_col2" class="data row2 col2" >0.98</td>
#       <td id="T_e436f_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_e436f_row2_col4" class="data row2 col4" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_e436f_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_e436f_row3_col0" class="data row3 col0" >5139.00</td>
#       <td id="T_e436f_row3_col1" class="data row3 col1" >104.00</td>
#       <td id="T_e436f_row3_col2" class="data row3 col2" >0.98</td>
#       <td id="T_e436f_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_e436f_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: other_weather
# ==================================================
# <style type="text/css">
# #T_4f2ae th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_4f2ae  {
#   border: 2px solid #333;
# }
# #T_4f2ae tbody td {
#   border: 1px solid #666;
# }
# #T_4f2ae_row0_col0, #T_4f2ae_row0_col2, #T_4f2ae_row1_col0, #T_4f2ae_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_4f2ae_row0_col1, #T_4f2ae_row1_col1, #T_4f2ae_row2_col1, #T_4f2ae_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_4f2ae_row0_col3, #T_4f2ae_row0_col4, #T_4f2ae_row1_col2, #T_4f2ae_row1_col3, #T_4f2ae_row1_col4, #T_4f2ae_row2_col2, #T_4f2ae_row2_col3, #T_4f2ae_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4f2ae_row3_col0, #T_4f2ae_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_4f2ae_row3_col3, #T_4f2ae_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_4f2ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f2ae_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4f2ae_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4f2ae_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_4f2ae_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_4f2ae_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f2ae_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_4f2ae_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_4f2ae_row0_col1" class="data row0 col1" >0.29</td>
#       <td id="T_4f2ae_row0_col2" class="data row0 col2" >0.95</td>
#       <td id="T_4f2ae_row0_col3" class="data row0 col3" >0.62</td>
#       <td id="T_4f2ae_row0_col4" class="data row0 col4" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_4f2ae_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_4f2ae_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_4f2ae_row1_col1" class="data row1 col1" >0.01</td>
#       <td id="T_4f2ae_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_4f2ae_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_4f2ae_row1_col4" class="data row1 col4" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_4f2ae_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_4f2ae_row2_col0" class="data row2 col0" >0.97</td>
#       <td id="T_4f2ae_row2_col1" class="data row2 col1" >0.01</td>
#       <td id="T_4f2ae_row2_col2" class="data row2 col2" >0.95</td>
#       <td id="T_4f2ae_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_4f2ae_row2_col4" class="data row2 col4" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_4f2ae_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_4f2ae_row3_col0" class="data row3 col0" >4976.00</td>
#       <td id="T_4f2ae_row3_col1" class="data row3 col1" >267.00</td>
#       <td id="T_4f2ae_row3_col2" class="data row3 col2" >0.95</td>
#       <td id="T_4f2ae_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_4f2ae_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Category: direct_report
# ==================================================
# <style type="text/css">
# #T_a0112 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_a0112  {
#   border: 2px solid #333;
# }
# #T_a0112 tbody td {
#   border: 1px solid #666;
# }
# #T_a0112_row0_col0, #T_a0112_row1_col0, #T_a0112_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #8cc2dd;
# }
# #T_a0112_row0_col1, #T_a0112_row1_col1, #T_a0112_row2_col1, #T_a0112_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   background-color: #ffe5cc;
# }
# #T_a0112_row0_col2, #T_a0112_row0_col3, #T_a0112_row0_col4, #T_a0112_row1_col2, #T_a0112_row1_col3, #T_a0112_row1_col4, #T_a0112_row2_col2, #T_a0112_row2_col3, #T_a0112_row2_col4 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a0112_row3_col0, #T_a0112_row3_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_a0112_row3_col3, #T_a0112_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
#   background-color: #8cc2dd;
# }
# </style>
# <table id="T_a0112">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0112_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a0112_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a0112_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_a0112_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_a0112_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0112_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_a0112_row0_col0" class="data row0 col0" >0.87</td>
#       <td id="T_a0112_row0_col1" class="data row0 col1" >0.76</td>
#       <td id="T_a0112_row0_col2" class="data row0 col2" >0.86</td>
#       <td id="T_a0112_row0_col3" class="data row0 col3" >0.82</td>
#       <td id="T_a0112_row0_col4" class="data row0 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_a0112_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_a0112_row1_col0" class="data row1 col0" >0.97</td>
#       <td id="T_a0112_row1_col1" class="data row1 col1" >0.42</td>
#       <td id="T_a0112_row1_col2" class="data row1 col2" >0.86</td>
#       <td id="T_a0112_row1_col3" class="data row1 col3" >0.69</td>
#       <td id="T_a0112_row1_col4" class="data row1 col4" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_a0112_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_a0112_row2_col0" class="data row2 col0" >0.92</td>
#       <td id="T_a0112_row2_col1" class="data row2 col1" >0.54</td>
#       <td id="T_a0112_row2_col2" class="data row2 col2" >0.86</td>
#       <td id="T_a0112_row2_col3" class="data row2 col3" >0.73</td>
#       <td id="T_a0112_row2_col4" class="data row2 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_a0112_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_a0112_row3_col0" class="data row3 col0" >4233.00</td>
#       <td id="T_a0112_row3_col1" class="data row3 col1" >1010.00</td>
#       <td id="T_a0112_row3_col2" class="data row3 col2" >0.86</td>
#       <td id="T_a0112_row3_col3" class="data row3 col3" >5243.00</td>
#       <td id="T_a0112_row3_col4" class="data row3 col4" >5243.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
def display_model_metrics(Y_test, Y_pred, category_names):
    """
    Display comprehensive metrics for model evaluation
    
    Parameters:
    y_test - DataFrame with true labels
    y_pred - Array with predictions (can be 1D or 2D)
    category_names - List of category names
    """
    # Check dimensions of y_pred
    if len(Y_pred.shape) == 1:
        # If y_pred is 1D but evaluating multiple categories
        if len(category_names) > 1:
            print("Warning: y_pred is 1-dimensional but multiple categories provided.")
            print("Evaluating only the first category.")
            category_names = [category_names[0]]
            Y_test = Y_test.iloc[:, 0:1]
            # Reshape for consistent handling
            Y_pred = Y_pred.reshape(-1, 1)
    
    # Overall accuracy for each category
    accuracies = {}
    for idx, category in enumerate(category_names):
        accuracies[category] = accuracy_score(Y_test.iloc[:, idx], Y_pred[:, idx])
    
    # Create accuracy DataFrame
    acc_df = pd.DataFrame.from_dict(accuracies, orient='index', columns=['Accuracy'])
    print("\nOverall Accuracy for Each Category:")
    display(acc_df.style.background_gradient(cmap='YlOrBr')
           .format(precision=3)
           .set_caption('Model Accuracy by Category'))
    
    # Detailed metrics for each category
    print("\nDetailed Classification Metrics by Category:")
    for idx, category in enumerate(category_names):
        Y_true = Y_test.iloc[:, idx]
        Y_pred_cat = Y_pred[:, idx]  # Changed variable name to avoid conflict
        
        report = classification_report(Y_true, Y_pred_cat, output_dict=True, zero_division=0)
        df_report = pd.DataFrame(report).round(3)
        
        print(f'\n{"="*20}')
        print(f'Category: {category}')
        print(f'{"="*20}')
        
        styled_df = df_report.style\
            .background_gradient(cmap='YlOrBr')\
            .format(precision=3)\
            .set_table_styles([
                {'selector': 'th', 'props': [('background-color', '#eee'),
                                          ('color', '#000'),
                                          ('font-weight', 'bold')]},
                {'selector': '', 'props': [('border', '2px solid #333')]},
                {'selector': 'tbody td', 'props': [('border', '1px solid #666')]}
            ])
        
        display(styled_df)

# Get predictions from your best model
best_model = cv_pipeline.best_estimator_
Y_pred = best_model.predict(X_test)

print("Best Model Evaluation Metrics:")
print("=" * 40)  # Increased visibility
print("\nBest Parameters found by GridSearchCV:")
print(cv_pipeline.best_params_)

# Display comprehensive metrics
display_model_metrics(Y_test, Y_pred, category_names)

# Calculate and display average metrics across all categories
print("\nAverage Metrics Across All Categories:")
print("=" * 40)  # Increased visibility

# Fixed variable name (y_test instead of Y_test)
avg_metrics = {
    'Avg Accuracy': np.mean([accuracy_score(Y_test.iloc[:, i], Y_pred[:, i]) for i in range(len(category_names))]),
    'Avg Precision': np.mean([precision_score(Y_test.iloc[:, i], Y_pred[:, i], average='weighted', zero_division=0) 
                            for i in range(len(category_names))]),
    'Avg Recall': np.mean([recall_score(Y_test.iloc[:, i], Y_pred[:, i], average='weighted', zero_division=0) 
                          for i in range(len(category_names))])
}

avg_df = pd.DataFrame([avg_metrics])
display(avg_df.style.format(precision=3)
       .background_gradient(cmap='YlOrBr')
       .set_caption('Average Metrics Across All Categories'))
# Out:
# Best Model Evaluation Metrics:
# ========================================
#
# Best Parameters found by GridSearchCV:
# {'cvect__max_features': 100, 'cvect__ngram_range': (1, 1)}
#
# Overall Accuracy for Each Category:
# <style type="text/css">
# #T_238d5_row0_col0 {
#   background-color: #fee595;
#   color: #000000;
# }
# #T_238d5_row1_col0 {
#   background-color: #ec7014;
#   color: #f1f1f1;
# }
# #T_238d5_row2_col0, #T_238d5_row25_col0 {
#   background-color: #6c2706;
#   color: #f1f1f1;
# }
# #T_238d5_row3_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_238d5_row4_col0 {
#   background-color: #d95b09;
#   color: #f1f1f1;
# }
# #T_238d5_row5_col0 {
#   background-color: #b44103;
#   color: #f1f1f1;
# }
# #T_238d5_row6_col0 {
#   background-color: #8c3004;
#   color: #f1f1f1;
# }
# #T_238d5_row7_col0 {
#   background-color: #812d05;
#   color: #f1f1f1;
# }
# #T_238d5_row8_col0 {
#   background-color: #933204;
#   color: #f1f1f1;
# }
# #T_238d5_row9_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_238d5_row10_col0, #T_238d5_row32_col0 {
#   background-color: #a33904;
#   color: #f1f1f1;
# }
# #T_238d5_row11_col0 {
#   background-color: #b13f03;
#   color: #f1f1f1;
# }
# #T_238d5_row12_col0 {
#   background-color: #c44802;
#   color: #f1f1f1;
# }
# #T_238d5_row13_col0 {
#   background-color: #792b05;
#   color: #f1f1f1;
# }
# #T_238d5_row14_col0 {
#   background-color: #842e05;
#   color: #f1f1f1;
# }
# #T_238d5_row15_col0, #T_238d5_row26_col0 {
#   background-color: #782a05;
#   color: #f1f1f1;
# }
# #T_238d5_row16_col0 {
#   background-color: #963304;
#   color: #f1f1f1;
# }
# #T_238d5_row17_col0 {
#   background-color: #ab3c03;
#   color: #f1f1f1;
# }
# #T_238d5_row18_col0 {
#   background-color: #fa8f24;
#   color: #f1f1f1;
# }
# #T_238d5_row19_col0 {
#   background-color: #c64902;
#   color: #f1f1f1;
# }
# #T_238d5_row20_col0 {
#   background-color: #a93c03;
#   color: #f1f1f1;
# }
# #T_238d5_row21_col0 {
#   background-color: #ac3d03;
#   color: #f1f1f1;
# }
# #T_238d5_row22_col0 {
#   background-color: #862e05;
#   color: #f1f1f1;
# }
# #T_238d5_row23_col0 {
#   background-color: #702806;
#   color: #f1f1f1;
# }
# #T_238d5_row24_col0, #T_238d5_row31_col0 {
#   background-color: #742905;
#   color: #f1f1f1;
# }
# #T_238d5_row27_col0 {
#   background-color: #a63a03;
#   color: #f1f1f1;
# }
# #T_238d5_row28_col0 {
#   background-color: #fec550;
#   color: #000000;
# }
# #T_238d5_row29_col0 {
#   background-color: #bb4403;
#   color: #f1f1f1;
# }
# #T_238d5_row30_col0 {
#   background-color: #ce4f03;
#   color: #f1f1f1;
# }
# #T_238d5_row33_col0 {
#   background-color: #832d05;
#   color: #f1f1f1;
# }
# #T_238d5_row34_col0 {
#   background-color: #b34003;
#   color: #f1f1f1;
# }
# #T_238d5_row35_col0 {
#   background-color: #fe9a2a;
#   color: #000000;
# }
# </style>
# <table id="T_238d5">
#   <caption>Model Accuracy by Category</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_238d5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_238d5_level0_row0" class="row_heading level0 row0" >related</th>
#       <td id="T_238d5_row0_col0" class="data row0 col0" >0.791</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row1" class="row_heading level0 row1" >request</th>
#       <td id="T_238d5_row1_col0" class="data row1 col0" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row2" class="row_heading level0 row2" >offer</th>
#       <td id="T_238d5_row2_col0" class="data row2 col0" >0.995</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row3" class="row_heading level0 row3" >aid_related</th>
#       <td id="T_238d5_row3_col0" class="data row3 col0" >0.726</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row4" class="row_heading level0 row4" >medical_help</th>
#       <td id="T_238d5_row4_col0" class="data row4 col0" >0.917</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row5" class="row_heading level0 row5" >medical_products</th>
#       <td id="T_238d5_row5_col0" class="data row5 col0" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row6" class="row_heading level0 row6" >search_and_rescue</th>
#       <td id="T_238d5_row6_col0" class="data row6 col0" >0.974</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row7" class="row_heading level0 row7" >security</th>
#       <td id="T_238d5_row7_col0" class="data row7 col0" >0.982</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row8" class="row_heading level0 row8" >military</th>
#       <td id="T_238d5_row8_col0" class="data row8 col0" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row9" class="row_heading level0 row9" >child_alone</th>
#       <td id="T_238d5_row9_col0" class="data row9 col0" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row10" class="row_heading level0 row10" >water</th>
#       <td id="T_238d5_row10_col0" class="data row10 col0" >0.959</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row11" class="row_heading level0 row11" >food</th>
#       <td id="T_238d5_row11_col0" class="data row11 col0" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row12" class="row_heading level0 row12" >shelter</th>
#       <td id="T_238d5_row12_col0" class="data row12 col0" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row13" class="row_heading level0 row13" >clothing</th>
#       <td id="T_238d5_row13_col0" class="data row13 col0" >0.987</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row14" class="row_heading level0 row14" >money</th>
#       <td id="T_238d5_row14_col0" class="data row14 col0" >0.979</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row15" class="row_heading level0 row15" >missing_people</th>
#       <td id="T_238d5_row15_col0" class="data row15 col0" >0.988</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row16" class="row_heading level0 row16" >refugees</th>
#       <td id="T_238d5_row16_col0" class="data row16 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row17" class="row_heading level0 row17" >death</th>
#       <td id="T_238d5_row17_col0" class="data row17 col0" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row18" class="row_heading level0 row18" >other_aid</th>
#       <td id="T_238d5_row18_col0" class="data row18 col0" >0.871</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row19" class="row_heading level0 row19" >infrastructure_related</th>
#       <td id="T_238d5_row19_col0" class="data row19 col0" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row20" class="row_heading level0 row20" >transport</th>
#       <td id="T_238d5_row20_col0" class="data row20 col0" >0.955</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row21" class="row_heading level0 row21" >buildings</th>
#       <td id="T_238d5_row21_col0" class="data row21 col0" >0.952</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row22" class="row_heading level0 row22" >electricity</th>
#       <td id="T_238d5_row22_col0" class="data row22 col0" >0.978</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row23" class="row_heading level0 row23" >tools</th>
#       <td id="T_238d5_row23_col0" class="data row23 col0" >0.993</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row24" class="row_heading level0 row24" >hospitals</th>
#       <td id="T_238d5_row24_col0" class="data row24 col0" >0.990</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row25" class="row_heading level0 row25" >shops</th>
#       <td id="T_238d5_row25_col0" class="data row25 col0" >0.995</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row26" class="row_heading level0 row26" >aid_centers</th>
#       <td id="T_238d5_row26_col0" class="data row26 col0" >0.988</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row27" class="row_heading level0 row27" >other_infrastructure</th>
#       <td id="T_238d5_row27_col0" class="data row27 col0" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row28" class="row_heading level0 row28" >weather_related</th>
#       <td id="T_238d5_row28_col0" class="data row28 col0" >0.828</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row29" class="row_heading level0 row29" >floods</th>
#       <td id="T_238d5_row29_col0" class="data row29 col0" >0.943</td>
#     </tr>
#     <tr>
#       <th id="T_238d5_level0_row30" class="row_heading level0 row30" >storm</th>
#       <td id="T_238d5_row30_col0" class="data row30 col0" >0.928</td>
#     </tr>
#     <tr
# Detailed Classification Metrics by Category:
#
# ====================
# Category: related
# ====================
# <style type="text/css">
# #T_d2c8f th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_d2c8f  {
#   border: 2px solid #333;
# }
# #T_d2c8f tbody td {
#   border: 1px solid #666;
# }
# #T_d2c8f_row0_col0, #T_d2c8f_row0_col1, #T_d2c8f_row0_col2, #T_d2c8f_row0_col3, #T_d2c8f_row0_col4, #T_d2c8f_row1_col0, #T_d2c8f_row1_col1, #T_d2c8f_row1_col2, #T_d2c8f_row1_col3, #T_d2c8f_row1_col4, #T_d2c8f_row2_col0, #T_d2c8f_row2_col1, #T_d2c8f_row2_col2, #T_d2c8f_row2_col3, #T_d2c8f_row2_col4, #T_d2c8f_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_d2c8f_row3_col0, #T_d2c8f_row3_col1, #T_d2c8f_row3_col3, #T_d2c8f_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d2c8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2c8f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d2c8f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d2c8f_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_d2c8f_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_d2c8f_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2c8f_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_d2c8f_row0_col0" class="data row0 col0" >0.627</td>
#       <td id="T_d2c8f_row0_col1" class="data row0 col1" >0.812</td>
#       <td id="T_d2c8f_row0_col2" class="data row0 col2" >0.791</td>
#       <td id="T_d2c8f_row0_col3" class="data row0 col3" >0.719</td>
#       <td id="T_d2c8f_row0_col4" class="data row0 col4" >0.768</td>
#     </tr>
#     <tr>
#       <th id="T_d2c8f_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_d2c8f_row1_col0" class="data row1 col0" >0.295</td>
#       <td id="T_d2c8f_row1_col1" class="data row1 col1" >0.945</td>
#       <td id="T_d2c8f_row1_col2" class="data row1 col2" >0.791</td>
#       <td id="T_d2c8f_row1_col3" class="data row1 col3" >0.620</td>
#       <td id="T_d2c8f_row1_col4" class="data row1 col4" >0.791</td>
#     </tr>
#     <tr>
#       <th id="T_d2c8f_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_d2c8f_row2_col0" class="data row2 col0" >0.401</td>
#       <td id="T_d2c8f_row2_col1" class="data row2 col1" >0.873</td>
#       <td id="T_d2c8f_row2_col2" class="data row2 col2" >0.791</td>
#       <td id="T_d2c8f_row2_col3" class="data row2 col3" >0.637</td>
#       <td id="T_d2c8f_row2_col4" class="data row2 col4" >0.761</td>
#     </tr>
#     <tr>
#       <th id="T_d2c8f_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_d2c8f_row3_col0" class="data row3 col0" >1245.000</td>
#       <td id="T_d2c8f_row3_col1" class="data row3 col1" >3998.000</td>
#       <td id="T_d2c8f_row3_col2" class="data row3 col2" >0.791</td>
#       <td id="T_d2c8f_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_d2c8f_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: request
# ====================
# <style type="text/css">
# #T_de347 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_de347  {
#   border: 2px solid #333;
# }
# #T_de347 tbody td {
#   border: 1px solid #666;
# }
# #T_de347_row0_col0, #T_de347_row0_col1, #T_de347_row0_col2, #T_de347_row0_col3, #T_de347_row0_col4, #T_de347_row1_col0, #T_de347_row1_col1, #T_de347_row1_col2, #T_de347_row1_col3, #T_de347_row1_col4, #T_de347_row2_col0, #T_de347_row2_col1, #T_de347_row2_col2, #T_de347_row2_col3, #T_de347_row2_col4, #T_de347_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_de347_row3_col0, #T_de347_row3_col1, #T_de347_row3_col3, #T_de347_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de347">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de347_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_de347_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_de347_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_de347_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_de347_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de347_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_de347_row0_col0" class="data row0 col0" >0.906</td>
#       <td id="T_de347_row0_col1" class="data row0 col1" >0.815</td>
#       <td id="T_de347_row0_col2" class="data row0 col2" >0.896</td>
#       <td id="T_de347_row0_col3" class="data row0 col3" >0.860</td>
#       <td id="T_de347_row0_col4" class="data row0 col4" >0.890</td>
#     </tr>
#     <tr>
#       <th id="T_de347_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_de347_row1_col0" class="data row1 col0" >0.977</td>
#       <td id="T_de347_row1_col1" class="data row1 col1" >0.503</td>
#       <td id="T_de347_row1_col2" class="data row1 col2" >0.896</td>
#       <td id="T_de347_row1_col3" class="data row1 col3" >0.740</td>
#       <td id="T_de347_row1_col4" class="data row1 col4" >0.896</td>
#     </tr>
#     <tr>
#       <th id="T_de347_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_de347_row2_col0" class="data row2 col0" >0.940</td>
#       <td id="T_de347_row2_col1" class="data row2 col1" >0.622</td>
#       <td id="T_de347_row2_col2" class="data row2 col2" >0.896</td>
#       <td id="T_de347_row2_col3" class="data row2 col3" >0.781</td>
#       <td id="T_de347_row2_col4" class="data row2 col4" >0.886</td>
#     </tr>
#     <tr>
#       <th id="T_de347_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_de347_row3_col0" class="data row3 col0" >4352.000</td>
#       <td id="T_de347_row3_col1" class="data row3 col1" >891.000</td>
#       <td id="T_de347_row3_col2" class="data row3 col2" >0.896</td>
#       <td id="T_de347_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_de347_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: offer
# ====================
# <style type="text/css">
# #T_a55ef th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_a55ef  {
#   border: 2px solid #333;
# }
# #T_a55ef tbody td {
#   border: 1px solid #666;
# }
# #T_a55ef_row0_col0, #T_a55ef_row0_col1, #T_a55ef_row0_col2, #T_a55ef_row0_col3, #T_a55ef_row0_col4, #T_a55ef_row1_col0, #T_a55ef_row1_col1, #T_a55ef_row1_col2, #T_a55ef_row1_col3, #T_a55ef_row1_col4, #T_a55ef_row2_col0, #T_a55ef_row2_col1, #T_a55ef_row2_col2, #T_a55ef_row2_col3, #T_a55ef_row2_col4, #T_a55ef_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a55ef_row3_col0, #T_a55ef_row3_col1, #T_a55ef_row3_col3, #T_a55ef_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a55ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a55ef_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a55ef_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a55ef_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_a55ef_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_a55ef_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a55ef_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_a55ef_row0_col0" class="data row0 col0" >0.995</td>
#       <td id="T_a55ef_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_a55ef_row0_col2" class="data row0 col2" >0.995</td>
#       <td id="T_a55ef_row0_col3" class="data row0 col3" >0.498</td>
#       <td id="T_a55ef_row0_col4" class="data row0 col4" >0.991</td>
#     </tr>
#     <tr>
#       <th id="T_a55ef_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_a55ef_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_a55ef_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_a55ef_row1_col2" class="data row1 col2" >0.995</td>
#       <td id="T_a55ef_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_a55ef_row1_col4" class="data row1 col4" >0.995</td>
#     </tr>
#     <tr>
#       <th id="T_a55ef_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_a55ef_row2_col0" class="data row2 col0" >0.998</td>
#       <td id="T_a55ef_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_a55ef_row2_col2" class="data row2 col2" >0.995</td>
#       <td id="T_a55ef_row2_col3" class="data row2 col3" >0.499</td>
#       <td id="T_a55ef_row2_col4" class="data row2 col4" >0.993</td>
#     </tr>
#     <tr>
#       <th id="T_a55ef_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_a55ef_row3_col0" class="data row3 col0" >5219.000</td>
#       <td id="T_a55ef_row3_col1" class="data row3 col1" >24.000</td>
#       <td id="T_a55ef_row3_col2" class="data row3 col2" >0.995</td>
#       <td id="T_a55ef_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_a55ef_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: aid_related
# ====================
# <style type="text/css">
# #T_e4db4 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_e4db4  {
#   border: 2px solid #333;
# }
# #T_e4db4 tbody td {
#   border: 1px solid #666;
# }
# #T_e4db4_row0_col0, #T_e4db4_row0_col1, #T_e4db4_row0_col2, #T_e4db4_row0_col3, #T_e4db4_row0_col4, #T_e4db4_row1_col0, #T_e4db4_row1_col1, #T_e4db4_row1_col2, #T_e4db4_row1_col3, #T_e4db4_row1_col4, #T_e4db4_row2_col0, #T_e4db4_row2_col1, #T_e4db4_row2_col2, #T_e4db4_row2_col3, #T_e4db4_row2_col4, #T_e4db4_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e4db4_row3_col0, #T_e4db4_row3_col1, #T_e4db4_row3_col3, #T_e4db4_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4db4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4db4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e4db4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e4db4_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_e4db4_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_e4db4_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4db4_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_e4db4_row0_col0" class="data row0 col0" >0.731</td>
#       <td id="T_e4db4_row0_col1" class="data row0 col1" >0.715</td>
#       <td id="T_e4db4_row0_col2" class="data row0 col2" >0.726</td>
#       <td id="T_e4db4_row0_col3" class="data row0 col3" >0.723</td>
#       <td id="T_e4db4_row0_col4" class="data row0 col4" >0.724</td>
#     </tr>
#     <tr>
#       <th id="T_e4db4_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_e4db4_row1_col0" class="data row1 col0" >0.843</td>
#       <td id="T_e4db4_row1_col1" class="data row1 col1" >0.558</td>
#       <td id="T_e4db4_row1_col2" class="data row1 col2" >0.726</td>
#       <td id="T_e4db4_row1_col3" class="data row1 col3" >0.701</td>
#       <td id="T_e4db4_row1_col4" class="data row1 col4" >0.726</td>
#     </tr>
#     <tr>
#       <th id="T_e4db4_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_e4db4_row2_col0" class="data row2 col0" >0.783</td>
#       <td id="T_e4db4_row2_col1" class="data row2 col1" >0.627</td>
#       <td id="T_e4db4_row2_col2" class="data row2 col2" >0.726</td>
#       <td id="T_e4db4_row2_col3" class="data row2 col3" >0.705</td>
#       <td id="T_e4db4_row2_col4" class="data row2 col4" >0.718</td>
#     </tr>
#     <tr>
#       <th id="T_e4db4_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_e4db4_row3_col0" class="data row3 col0" >3079.000</td>
#       <td id="T_e4db4_row3_col1" class="data row3 col1" >2164.000</td>
#       <td id="T_e4db4_row3_col2" class="data row3 col2" >0.726</td>
#       <td id="T_e4db4_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_e4db4_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: medical_help
# ====================
# <style type="text/css">
# #T_aa321 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_aa321  {
#   border: 2px solid #333;
# }
# #T_aa321 tbody td {
#   border: 1px solid #666;
# }
# #T_aa321_row0_col0, #T_aa321_row0_col1, #T_aa321_row0_col2, #T_aa321_row0_col3, #T_aa321_row0_col4, #T_aa321_row1_col0, #T_aa321_row1_col1, #T_aa321_row1_col2, #T_aa321_row1_col3, #T_aa321_row1_col4, #T_aa321_row2_col0, #T_aa321_row2_col1, #T_aa321_row2_col2, #T_aa321_row2_col3, #T_aa321_row2_col4, #T_aa321_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_aa321_row3_col0, #T_aa321_row3_col1, #T_aa321_row3_col3, #T_aa321_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aa321">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa321_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_aa321_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_aa321_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_aa321_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_aa321_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa321_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_aa321_row0_col0" class="data row0 col0" >0.918</td>
#       <td id="T_aa321_row0_col1" class="data row0 col1" >0.417</td>
#       <td id="T_aa321_row0_col2" class="data row0 col2" >0.917</td>
#       <td id="T_aa321_row0_col3" class="data row0 col3" >0.667</td>
#       <td id="T_aa321_row0_col4" class="data row0 col4" >0.876</td>
#     </tr>
#     <tr>
#       <th id="T_aa321_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_aa321_row1_col0" class="data row1 col0" >0.999</td>
#       <td id="T_aa321_row1_col1" class="data row1 col1" >0.011</td>
#       <td id="T_aa321_row1_col2" class="data row1 col2" >0.917</td>
#       <td id="T_aa321_row1_col3" class="data row1 col3" >0.505</td>
#       <td id="T_aa321_row1_col4" class="data row1 col4" >0.917</td>
#     </tr>
#     <tr>
#       <th id="T_aa321_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_aa321_row2_col0" class="data row2 col0" >0.956</td>
#       <td id="T_aa321_row2_col1" class="data row2 col1" >0.022</td>
#       <td id="T_aa321_row2_col2" class="data row2 col2" >0.917</td>
#       <td id="T_aa321_row2_col3" class="data row2 col3" >0.489</td>
#       <td id="T_aa321_row2_col4" class="data row2 col4" >0.879</td>
#     </tr>
#     <tr>
#       <th id="T_aa321_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_aa321_row3_col0" class="data row3 col0" >4808.000</td>
#       <td id="T_aa321_row3_col1" class="data row3 col1" >435.000</td>
#       <td id="T_aa321_row3_col2" class="data row3 col2" >0.917</td>
#       <td id="T_aa321_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_aa321_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: medical_products
# ====================
# <style type="text/css">
# #T_19837 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_19837  {
#   border: 2px solid #333;
# }
# #T_19837 tbody td {
#   border: 1px solid #666;
# }
# #T_19837_row0_col0, #T_19837_row0_col1, #T_19837_row0_col2, #T_19837_row0_col3, #T_19837_row0_col4, #T_19837_row1_col0, #T_19837_row1_col1, #T_19837_row1_col2, #T_19837_row1_col3, #T_19837_row1_col4, #T_19837_row2_col0, #T_19837_row2_col1, #T_19837_row2_col2, #T_19837_row2_col3, #T_19837_row2_col4, #T_19837_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_19837_row3_col0, #T_19837_row3_col1, #T_19837_row3_col3, #T_19837_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19837">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19837_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_19837_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_19837_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_19837_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_19837_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19837_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_19837_row0_col0" class="data row0 col0" >0.948</td>
#       <td id="T_19837_row0_col1" class="data row0 col1" >0.600</td>
#       <td id="T_19837_row0_col2" class="data row0 col2" >0.947</td>
#       <td id="T_19837_row0_col3" class="data row0 col3" >0.774</td>
#       <td id="T_19837_row0_col4" class="data row0 col4" >0.929</td>
#     </tr>
#     <tr>
#       <th id="T_19837_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_19837_row1_col0" class="data row1 col0" >0.999</td>
#       <td id="T_19837_row1_col1" class="data row1 col1" >0.022</td>
#       <td id="T_19837_row1_col2" class="data row1 col2" >0.947</td>
#       <td id="T_19837_row1_col3" class="data row1 col3" >0.510</td>
#       <td id="T_19837_row1_col4" class="data row1 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_19837_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_19837_row2_col0" class="data row2 col0" >0.973</td>
#       <td id="T_19837_row2_col1" class="data row2 col1" >0.042</td>
#       <td id="T_19837_row2_col2" class="data row2 col2" >0.947</td>
#       <td id="T_19837_row2_col3" class="data row2 col3" >0.507</td>
#       <td id="T_19837_row2_col4" class="data row2 col4" >0.923</td>
#     </tr>
#     <tr>
#       <th id="T_19837_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_19837_row3_col0" class="data row3 col0" >4964.000</td>
#       <td id="T_19837_row3_col1" class="data row3 col1" >279.000</td>
#       <td id="T_19837_row3_col2" class="data row3 col2" >0.947</td>
#       <td id="T_19837_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_19837_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: search_and_rescue
# ====================
# <style type="text/css">
# #T_321c5 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_321c5  {
#   border: 2px solid #333;
# }
# #T_321c5 tbody td {
#   border: 1px solid #666;
# }
# #T_321c5_row0_col0, #T_321c5_row0_col1, #T_321c5_row0_col2, #T_321c5_row0_col3, #T_321c5_row0_col4, #T_321c5_row1_col0, #T_321c5_row1_col1, #T_321c5_row1_col2, #T_321c5_row1_col3, #T_321c5_row1_col4, #T_321c5_row2_col0, #T_321c5_row2_col1, #T_321c5_row2_col2, #T_321c5_row2_col3, #T_321c5_row2_col4, #T_321c5_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_321c5_row3_col0, #T_321c5_row3_col1, #T_321c5_row3_col3, #T_321c5_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_321c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_321c5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_321c5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_321c5_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_321c5_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_321c5_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_321c5_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_321c5_row0_col0" class="data row0 col0" >0.974</td>
#       <td id="T_321c5_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_321c5_row0_col2" class="data row0 col2" >0.974</td>
#       <td id="T_321c5_row0_col3" class="data row0 col3" >0.487</td>
#       <td id="T_321c5_row0_col4" class="data row0 col4" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_321c5_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_321c5_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_321c5_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_321c5_row1_col2" class="data row1 col2" >0.974</td>
#       <td id="T_321c5_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_321c5_row1_col4" class="data row1 col4" >0.974</td>
#     </tr>
#     <tr>
#       <th id="T_321c5_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_321c5_row2_col0" class="data row2 col0" >0.987</td>
#       <td id="T_321c5_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_321c5_row2_col2" class="data row2 col2" >0.974</td>
#       <td id="T_321c5_row2_col3" class="data row2 col3" >0.493</td>
#       <td id="T_321c5_row2_col4" class="data row2 col4" >0.961</td>
#     </tr>
#     <tr>
#       <th id="T_321c5_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_321c5_row3_col0" class="data row3 col0" >5107.000</td>
#       <td id="T_321c5_row3_col1" class="data row3 col1" >136.000</td>
#       <td id="T_321c5_row3_col2" class="data row3 col2" >0.974</td>
#       <td id="T_321c5_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_321c5_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: security
# ====================
# <style type="text/css">
# #T_f062a th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_f062a  {
#   border: 2px solid #333;
# }
# #T_f062a tbody td {
#   border: 1px solid #666;
# }
# #T_f062a_row0_col0, #T_f062a_row0_col2, #T_f062a_row0_col3, #T_f062a_row0_col4, #T_f062a_row1_col0, #T_f062a_row1_col1, #T_f062a_row1_col2, #T_f062a_row1_col3, #T_f062a_row1_col4, #T_f062a_row2_col0, #T_f062a_row2_col1, #T_f062a_row2_col2, #T_f062a_row2_col3, #T_f062a_row2_col4, #T_f062a_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f062a_row0_col1 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_f062a_row3_col0, #T_f062a_row3_col1, #T_f062a_row3_col3, #T_f062a_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f062a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f062a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f062a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f062a_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_f062a_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_f062a_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f062a_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_f062a_row0_col0" class="data row0 col0" >0.982</td>
#       <td id="T_f062a_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_f062a_row0_col2" class="data row0 col2" >0.982</td>
#       <td id="T_f062a_row0_col3" class="data row0 col3" >0.741</td>
#       <td id="T_f062a_row0_col4" class="data row0 col4" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_f062a_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_f062a_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_f062a_row1_col1" class="data row1 col1" >0.010</td>
#       <td id="T_f062a_row1_col2" class="data row1 col2" >0.982</td>
#       <td id="T_f062a_row1_col3" class="data row1 col3" >0.505</td>
#       <td id="T_f062a_row1_col4" class="data row1 col4" >0.982</td>
#     </tr>
#     <tr>
#       <th id="T_f062a_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_f062a_row2_col0" class="data row2 col0" >0.991</td>
#       <td id="T_f062a_row2_col1" class="data row2 col1" >0.020</td>
#       <td id="T_f062a_row2_col2" class="data row2 col2" >0.982</td>
#       <td id="T_f062a_row2_col3" class="data row2 col3" >0.506</td>
#       <td id="T_f062a_row2_col4" class="data row2 col4" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_f062a_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_f062a_row3_col0" class="data row3 col0" >5147.000</td>
#       <td id="T_f062a_row3_col1" class="data row3 col1" >96.000</td>
#       <td id="T_f062a_row3_col2" class="data row3 col2" >0.982</td>
#       <td id="T_f062a_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_f062a_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: military
# ====================
# <style type="text/css">
# #T_61744 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_61744  {
#   border: 2px solid #333;
# }
# #T_61744 tbody td {
#   border: 1px solid #666;
# }
# #T_61744_row0_col0, #T_61744_row0_col1, #T_61744_row0_col2, #T_61744_row0_col3, #T_61744_row0_col4, #T_61744_row1_col0, #T_61744_row1_col1, #T_61744_row1_col2, #T_61744_row1_col3, #T_61744_row1_col4, #T_61744_row2_col0, #T_61744_row2_col1, #T_61744_row2_col2, #T_61744_row2_col3, #T_61744_row2_col4, #T_61744_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_61744_row3_col0, #T_61744_row3_col1, #T_61744_row3_col3, #T_61744_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61744">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61744_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_61744_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_61744_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_61744_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_61744_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61744_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_61744_row0_col0" class="data row0 col0" >0.970</td>
#       <td id="T_61744_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_61744_row0_col2" class="data row0 col2" >0.969</td>
#       <td id="T_61744_row0_col3" class="data row0 col3" >0.485</td>
#       <td id="T_61744_row0_col4" class="data row0 col4" >0.941</td>
#     </tr>
#     <tr>
#       <th id="T_61744_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_61744_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_61744_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_61744_row1_col2" class="data row1 col2" >0.969</td>
#       <td id="T_61744_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_61744_row1_col4" class="data row1 col4" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_61744_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_61744_row2_col0" class="data row2 col0" >0.985</td>
#       <td id="T_61744_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_61744_row2_col2" class="data row2 col2" >0.969</td>
#       <td id="T_61744_row2_col3" class="data row2 col3" >0.492</td>
#       <td id="T_61744_row2_col4" class="data row2 col4" >0.955</td>
#     </tr>
#     <tr>
#       <th id="T_61744_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_61744_row3_col0" class="data row3 col0" >5085.000</td>
#       <td id="T_61744_row3_col1" class="data row3 col1" >158.000</td>
#       <td id="T_61744_row3_col2" class="data row3 col2" >0.969</td>
#       <td id="T_61744_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_61744_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: child_alone
# ====================
# <style type="text/css">
# #T_2b89d th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_2b89d  {
#   border: 2px solid #333;
# }
# #T_2b89d tbody td {
#   border: 1px solid #666;
# }
# #T_2b89d_row0_col0, #T_2b89d_row0_col1, #T_2b89d_row0_col2, #T_2b89d_row0_col3, #T_2b89d_row1_col0, #T_2b89d_row1_col1, #T_2b89d_row1_col2, #T_2b89d_row1_col3, #T_2b89d_row2_col0, #T_2b89d_row2_col1, #T_2b89d_row2_col2, #T_2b89d_row2_col3, #T_2b89d_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_2b89d_row3_col0, #T_2b89d_row3_col2, #T_2b89d_row3_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2b89d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b89d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2b89d_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_2b89d_level0_col2" class="col_heading level0 col2" >macro avg</th>
#       <th id="T_2b89d_level0_col3" class="col_heading level0 col3" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b89d_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_2b89d_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_2b89d_row0_col1" class="data row0 col1" >1.000</td>
#       <td id="T_2b89d_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_2b89d_row0_col3" class="data row0 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_2b89d_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_2b89d_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_2b89d_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_2b89d_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_2b89d_row1_col3" class="data row1 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_2b89d_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_2b89d_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_2b89d_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_2b89d_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_2b89d_row2_col3" class="data row2 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_2b89d_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_2b89d_row3_col0" class="data row3 col0" >5243.000</td>
#       <td id="T_2b89d_row3_col1" class="data row3 col1" >1.000</td>
#       <td id="T_2b89d_row3_col2" class="data row3 col2" >5243.000</td>
#       <td id="T_2b89d_row3_col3" class="data row3 col3" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: water
# ====================
# <style type="text/css">
# #T_4091f th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_4091f  {
#   border: 2px solid #333;
# }
# #T_4091f tbody td {
#   border: 1px solid #666;
# }
# #T_4091f_row0_col0, #T_4091f_row0_col1, #T_4091f_row0_col2, #T_4091f_row0_col3, #T_4091f_row0_col4, #T_4091f_row1_col0, #T_4091f_row1_col1, #T_4091f_row1_col2, #T_4091f_row1_col3, #T_4091f_row1_col4, #T_4091f_row2_col0, #T_4091f_row2_col1, #T_4091f_row2_col2, #T_4091f_row2_col3, #T_4091f_row2_col4, #T_4091f_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4091f_row3_col0, #T_4091f_row3_col1, #T_4091f_row3_col3, #T_4091f_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4091f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4091f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4091f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4091f_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_4091f_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_4091f_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4091f_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_4091f_row0_col0" class="data row0 col0" >0.965</td>
#       <td id="T_4091f_row0_col1" class="data row0 col1" >0.810</td>
#       <td id="T_4091f_row0_col2" class="data row0 col2" >0.959</td>
#       <td id="T_4091f_row0_col3" class="data row0 col3" >0.888</td>
#       <td id="T_4091f_row0_col4" class="data row0 col4" >0.955</td>
#     </tr>
#     <tr>
#       <th id="T_4091f_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_4091f_row1_col0" class="data row1 col0" >0.992</td>
#       <td id="T_4091f_row1_col1" class="data row1 col1" >0.472</td>
#       <td id="T_4091f_row1_col2" class="data row1 col2" >0.959</td>
#       <td id="T_4091f_row1_col3" class="data row1 col3" >0.732</td>
#       <td id="T_4091f_row1_col4" class="data row1 col4" >0.959</td>
#     </tr>
#     <tr>
#       <th id="T_4091f_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_4091f_row2_col0" class="data row2 col0" >0.979</td>
#       <td id="T_4091f_row2_col1" class="data row2 col1" >0.596</td>
#       <td id="T_4091f_row2_col2" class="data row2 col2" >0.959</td>
#       <td id="T_4091f_row2_col3" class="data row2 col3" >0.787</td>
#       <td id="T_4091f_row2_col4" class="data row2 col4" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_4091f_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_4091f_row3_col0" class="data row3 col0" >4908.000</td>
#       <td id="T_4091f_row3_col1" class="data row3 col1" >335.000</td>
#       <td id="T_4091f_row3_col2" class="data row3 col2" >0.959</td>
#       <td id="T_4091f_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_4091f_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: food
# ====================
# <style type="text/css">
# #T_7c867 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_7c867  {
#   border: 2px solid #333;
# }
# #T_7c867 tbody td {
#   border: 1px solid #666;
# }
# #T_7c867_row0_col0, #T_7c867_row0_col1, #T_7c867_row0_col2, #T_7c867_row0_col3, #T_7c867_row0_col4, #T_7c867_row1_col0, #T_7c867_row1_col1, #T_7c867_row1_col2, #T_7c867_row1_col3, #T_7c867_row1_col4, #T_7c867_row2_col0, #T_7c867_row2_col1, #T_7c867_row2_col2, #T_7c867_row2_col3, #T_7c867_row2_col4, #T_7c867_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_7c867_row3_col0, #T_7c867_row3_col1, #T_7c867_row3_col3, #T_7c867_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c867">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c867_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7c867_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7c867_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_7c867_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_7c867_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c867_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_7c867_row0_col0" class="data row0 col0" >0.960</td>
#       <td id="T_7c867_row0_col1" class="data row0 col1" >0.833</td>
#       <td id="T_7c867_row0_col2" class="data row0 col2" >0.949</td>
#       <td id="T_7c867_row0_col3" class="data row0 col3" >0.897</td>
#       <td id="T_7c867_row0_col4" class="data row0 col4" >0.946</td>
#     </tr>
#     <tr>
#       <th id="T_7c867_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_7c867_row1_col0" class="data row1 col0" >0.983</td>
#       <td id="T_7c867_row1_col1" class="data row1 col1" >0.676</td>
#       <td id="T_7c867_row1_col2" class="data row1 col2" >0.949</td>
#       <td id="T_7c867_row1_col3" class="data row1 col3" >0.830</td>
#       <td id="T_7c867_row1_col4" class="data row1 col4" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_7c867_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_7c867_row2_col0" class="data row2 col0" >0.972</td>
#       <td id="T_7c867_row2_col1" class="data row2 col1" >0.747</td>
#       <td id="T_7c867_row2_col2" class="data row2 col2" >0.949</td>
#       <td id="T_7c867_row2_col3" class="data row2 col3" >0.859</td>
#       <td id="T_7c867_row2_col4" class="data row2 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_7c867_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_7c867_row3_col0" class="data row3 col0" >4659.000</td>
#       <td id="T_7c867_row3_col1" class="data row3 col1" >584.000</td>
#       <td id="T_7c867_row3_col2" class="data row3 col2" >0.949</td>
#       <td id="T_7c867_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_7c867_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: shelter
# ====================
# <style type="text/css">
# #T_f2b53 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_f2b53  {
#   border: 2px solid #333;
# }
# #T_f2b53 tbody td {
#   border: 1px solid #666;
# }
# #T_f2b53_row0_col0, #T_f2b53_row0_col1, #T_f2b53_row0_col2, #T_f2b53_row0_col3, #T_f2b53_row0_col4, #T_f2b53_row1_col0, #T_f2b53_row1_col1, #T_f2b53_row1_col2, #T_f2b53_row1_col3, #T_f2b53_row1_col4, #T_f2b53_row2_col0, #T_f2b53_row2_col1, #T_f2b53_row2_col2, #T_f2b53_row2_col3, #T_f2b53_row2_col4, #T_f2b53_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f2b53_row3_col0, #T_f2b53_row3_col1, #T_f2b53_row3_col3, #T_f2b53_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2b53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2b53_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f2b53_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f2b53_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_f2b53_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_f2b53_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2b53_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_f2b53_row0_col0" class="data row0 col0" >0.940</td>
#       <td id="T_f2b53_row0_col1" class="data row0 col1" >0.832</td>
#       <td id="T_f2b53_row0_col2" class="data row0 col2" >0.936</td>
#       <td id="T_f2b53_row0_col3" class="data row0 col3" >0.886</td>
#       <td id="T_f2b53_row0_col4" class="data row0 col4" >0.931</td>
#     </tr>
#     <tr>
#       <th id="T_f2b53_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_f2b53_row1_col0" class="data row1 col0" >0.993</td>
#       <td id="T_f2b53_row1_col1" class="data row1 col1" >0.359</td>
#       <td id="T_f2b53_row1_col2" class="data row1 col2" >0.936</td>
#       <td id="T_f2b53_row1_col3" class="data row1 col3" >0.676</td>
#       <td id="T_f2b53_row1_col4" class="data row1 col4" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_f2b53_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_f2b53_row2_col0" class="data row2 col0" >0.966</td>
#       <td id="T_f2b53_row2_col1" class="data row2 col1" >0.501</td>
#       <td id="T_f2b53_row2_col2" class="data row2 col2" >0.936</td>
#       <td id="T_f2b53_row2_col3" class="data row2 col3" >0.734</td>
#       <td id="T_f2b53_row2_col4" class="data row2 col4" >0.925</td>
#     </tr>
#     <tr>
#       <th id="T_f2b53_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_f2b53_row3_col0" class="data row3 col0" >4775.000</td>
#       <td id="T_f2b53_row3_col1" class="data row3 col1" >468.000</td>
#       <td id="T_f2b53_row3_col2" class="data row3 col2" >0.936</td>
#       <td id="T_f2b53_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_f2b53_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: clothing
# ====================
# <style type="text/css">
# #T_cfe51 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_cfe51  {
#   border: 2px solid #333;
# }
# ...
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_16086_row3_col0, #T_16086_row3_col1, #T_16086_row3_col3, #T_16086_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16086">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16086_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_16086_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_16086_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_16086_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_16086_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16086_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_16086_row0_col0" class="data row0 col0" >0.990</td>
#       <td id="T_16086_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_16086_row0_col2" class="data row0 col2" >0.990</td>
#       <td id="T_16086_row0_col3" class="data row0 col3" >0.495</td>
#       <td id="T_16086_row0_col4" class="data row0 col4" >0.980</td>
#     </tr>
#     <tr>
#       <th id="T_16086_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_16086_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_16086_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_16086_row1_col2" class="data row1 col2" >0.990</td>
#       <td id="T_16086_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_16086_row1_col4" class="data row1 col4" >0.990</td>
#     </tr>
#     <tr>
#       <th id="T_16086_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_16086_row2_col0" class="data row2 col0" >0.995</td>
#       <td id="T_16086_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_16086_row2_col2" class="data row2 col2" >0.990</td>
#       <td id="T_16086_row2_col3" class="data row2 col3" >0.497</td>
#       <td id="T_16086_row2_col4" class="data row2 col4" >0.985</td>
#     </tr>
#     <tr>
#       <th id="T_16086_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_16086_row3_col0" class="data row3 col0" >5190.000</td>
#       <td id="T_16086_row3_col1" class="data row3 col1" >53.000</td>
#       <td id="T_16086_row3_col2" class="data row3 col2" >0.990</td>
#       <td id="T_16086_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_16086_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: earthquake
# ====================
# <style type="text/css">
# #T_2dc1d th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_2dc1d  {
#   border: 2px solid #333;
# }
# #T_2dc1d tbody td {
#   border: 1px solid #666;
# }
# #T_2dc1d_row0_col0, #T_2dc1d_row0_col1, #T_2dc1d_row0_col2, #T_2dc1d_row0_col3, #T_2dc1d_row0_col4, #T_2dc1d_row1_col0, #T_2dc1d_row1_col1, #T_2dc1d_row1_col2, #T_2dc1d_row1_col3, #T_2dc1d_row1_col4, #T_2dc1d_row2_col0, #T_2dc1d_row2_col1, #T_2dc1d_row2_col2, #T_2dc1d_row2_col3, #T_2dc1d_row2_col4, #T_2dc1d_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_2dc1d_row3_col0, #T_2dc1d_row3_col1, #T_2dc1d_row3_col3, #T_2dc1d_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2dc1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dc1d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2dc1d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2dc1d_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_2dc1d_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_2dc1d_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dc1d_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_2dc1d_row0_col0" class="data row0 col0" >0.965</td>
#       <td id="T_2dc1d_row0_col1" class="data row0 col1" >0.889</td>
#       <td id="T_2dc1d_row0_col2" class="data row0 col2" >0.959</td>
#       <td id="T_2dc1d_row0_col3" class="data row0 col3" >0.927</td>
#       <td id="T_2dc1d_row0_col4" class="data row0 col4" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_2dc1d_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_2dc1d_row1_col0" class="data row1 col0" >0.991</td>
#       <td id="T_2dc1d_row1_col1" class="data row1 col1" >0.666</td>
#       <td id="T_2dc1d_row1_col2" class="data row1 col2" >0.959</td>
#       <td id="T_2dc1d_row1_col3" class="data row1 col3" >0.828</td>
#       <td id="T_2dc1d_row1_col4" class="data row1 col4" >0.959</td>
#     </tr>
#     <tr>
#       <th id="T_2dc1d_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_2dc1d_row2_col0" class="data row2 col0" >0.978</td>
#       <td id="T_2dc1d_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_2dc1d_row2_col2" class="data row2 col2" >0.959</td>
#       <td id="T_2dc1d_row2_col3" class="data row2 col3" >0.869</td>
#       <td id="T_2dc1d_row2_col4" class="data row2 col4" >0.956</td>
#     </tr>
#     <tr>
#       <th id="T_2dc1d_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_2dc1d_row3_col0" class="data row3 col0" >4728.000</td>
#       <td id="T_2dc1d_row3_col1" class="data row3 col1" >515.000</td>
#       <td id="T_2dc1d_row3_col2" class="data row3 col2" >0.959</td>
#       <td id="T_2dc1d_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_2dc1d_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: cold
# ====================
# <style type="text/css">
# #T_6da57 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_6da57  {
#   border: 2px solid #333;
# }
# #T_6da57 tbody td {
#   border: 1px solid #666;
# }
# #T_6da57_row0_col0, #T_6da57_row0_col1, #T_6da57_row0_col2, #T_6da57_row0_col3, #T_6da57_row0_col4, #T_6da57_row1_col0, #T_6da57_row1_col1, #T_6da57_row1_col2, #T_6da57_row1_col3, #T_6da57_row1_col4, #T_6da57_row2_col0, #T_6da57_row2_col1, #T_6da57_row2_col2, #T_6da57_row2_col3, #T_6da57_row2_col4, #T_6da57_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6da57_row3_col0, #T_6da57_row3_col1, #T_6da57_row3_col3, #T_6da57_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6da57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6da57_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6da57_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6da57_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_6da57_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_6da57_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6da57_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_6da57_row0_col0" class="data row0 col0" >0.980</td>
#       <td id="T_6da57_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_6da57_row0_col2" class="data row0 col2" >0.980</td>
#       <td id="T_6da57_row0_col3" class="data row0 col3" >0.490</td>
#       <td id="T_6da57_row0_col4" class="data row0 col4" >0.961</td>
#     </tr>
#     <tr>
#       <th id="T_6da57_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_6da57_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_6da57_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_6da57_row1_col2" class="data row1 col2" >0.980</td>
#       <td id="T_6da57_row1_col3" class="data row1 col3" >0.500</td>
#       <td id="T_6da57_row1_col4" class="data row1 col4" >0.980</td>
#     </tr>
#     <tr>
#       <th id="T_6da57_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_6da57_row2_col0" class="data row2 col0" >0.990</td>
#       <td id="T_6da57_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_6da57_row2_col2" class="data row2 col2" >0.980</td>
#       <td id="T_6da57_row2_col3" class="data row2 col3" >0.495</td>
#       <td id="T_6da57_row2_col4" class="data row2 col4" >0.970</td>
#     </tr>
#     <tr>
#       <th id="T_6da57_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_6da57_row3_col0" class="data row3 col0" >5139.000</td>
#       <td id="T_6da57_row3_col1" class="data row3 col1" >104.000</td>
#       <td id="T_6da57_row3_col2" class="data row3 col2" >0.980</td>
#       <td id="T_6da57_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_6da57_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: other_weather
# ====================
# <style type="text/css">
# #T_6a6be th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_6a6be  {
#   border: 2px solid #333;
# }
# #T_6a6be tbody td {
#   border: 1px solid #666;
# }
# #T_6a6be_row0_col0, #T_6a6be_row0_col1, #T_6a6be_row0_col2, #T_6a6be_row0_col3, #T_6a6be_row0_col4, #T_6a6be_row1_col0, #T_6a6be_row1_col1, #T_6a6be_row1_col2, #T_6a6be_row1_col3, #T_6a6be_row1_col4, #T_6a6be_row2_col0, #T_6a6be_row2_col1, #T_6a6be_row2_col2, #T_6a6be_row2_col3, #T_6a6be_row2_col4, #T_6a6be_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6a6be_row3_col0, #T_6a6be_row3_col1, #T_6a6be_row3_col3, #T_6a6be_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a6be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a6be_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6a6be_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6a6be_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_6a6be_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_6a6be_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a6be_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_6a6be_row0_col0" class="data row0 col0" >0.949</td>
#       <td id="T_6a6be_row0_col1" class="data row0 col1" >0.286</td>
#       <td id="T_6a6be_row0_col2" class="data row0 col2" >0.949</td>
#       <td id="T_6a6be_row0_col3" class="data row0 col3" >0.618</td>
#       <td id="T_6a6be_row0_col4" class="data row0 col4" >0.916</td>
#     </tr>
#     <tr>
#       <th id="T_6a6be_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_6a6be_row1_col0" class="data row1 col0" >0.999</td>
#       <td id="T_6a6be_row1_col1" class="data row1 col1" >0.007</td>
#       <td id="T_6a6be_row1_col2" class="data row1 col2" >0.949</td>
#       <td id="T_6a6be_row1_col3" class="data row1 col3" >0.503</td>
#       <td id="T_6a6be_row1_col4" class="data row1 col4" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_6a6be_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_6a6be_row2_col0" class="data row2 col0" >0.974</td>
#       <td id="T_6a6be_row2_col1" class="data row2 col1" >0.015</td>
#       <td id="T_6a6be_row2_col2" class="data row2 col2" >0.949</td>
#       <td id="T_6a6be_row2_col3" class="data row2 col3" >0.494</td>
#       <td id="T_6a6be_row2_col4" class="data row2 col4" >0.925</td>
#     </tr>
#     <tr>
#       <th id="T_6a6be_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_6a6be_row3_col0" class="data row3 col0" >4976.000</td>
#       <td id="T_6a6be_row3_col1" class="data row3 col1" >267.000</td>
#       <td id="T_6a6be_row3_col2" class="data row3 col2" >0.949</td>
#       <td id="T_6a6be_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_6a6be_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: direct_report
# ====================
# <style type="text/css">
# #T_dc30a th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_dc30a  {
#   border: 2px solid #333;
# }
# #T_dc30a tbody td {
#   border: 1px solid #666;
# }
# #T_dc30a_row0_col0, #T_dc30a_row0_col1, #T_dc30a_row0_col2, #T_dc30a_row0_col3, #T_dc30a_row0_col4, #T_dc30a_row1_col0, #T_dc30a_row1_col1, #T_dc30a_row1_col2, #T_dc30a_row1_col3, #T_dc30a_row1_col4, #T_dc30a_row2_col0, #T_dc30a_row2_col1, #T_dc30a_row2_col2, #T_dc30a_row2_col3, #T_dc30a_row2_col4, #T_dc30a_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_dc30a_row3_col0, #T_dc30a_row3_col1, #T_dc30a_row3_col3, #T_dc30a_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dc30a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc30a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_dc30a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_dc30a_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_dc30a_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_dc30a_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc30a_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_dc30a_row0_col0" class="data row0 col0" >0.874</td>
#       <td id="T_dc30a_row0_col1" class="data row0 col1" >0.759</td>
#       <td id="T_dc30a_row0_col2" class="data row0 col2" >0.862</td>
#       <td id="T_dc30a_row0_col3" class="data row0 col3" >0.816</td>
#       <td id="T_dc30a_row0_col4" class="data row0 col4" >0.852</td>
#     </tr>
#     <tr>
#       <th id="T_dc30a_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_dc30a_row1_col0" class="data row1 col0" >0.968</td>
#       <td id="T_dc30a_row1_col1" class="data row1 col1" >0.417</td>
#       <td id="T_dc30a_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_dc30a_row1_col3" class="data row1 col3" >0.693</td>
#       <td id="T_dc30a_row1_col4" class="data row1 col4" >0.862</td>
#     </tr>
#     <tr>
#       <th id="T_dc30a_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_dc30a_row2_col0" class="data row2 col0" >0.919</td>
#       <td id="T_dc30a_row2_col1" class="data row2 col1" >0.538</td>
#       <td id="T_dc30a_row2_col2" class="data row2 col2" >0.862</td>
#       <td id="T_dc30a_row2_col3" class="data row2 col3" >0.728</td>
#       <td id="T_dc30a_row2_col4" class="data row2 col4" >0.846</td>
#     </tr>
#     <tr>
#       <th id="T_dc30a_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_dc30a_row3_col0" class="data row3 col0" >4233.000</td>
#       <td id="T_dc30a_row3_col1" class="data row3 col1" >1010.000</td>
#       <td id="T_dc30a_row3_col2" class="data row3 col2" >0.862</td>
#       <td id="T_dc30a_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_dc30a_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# Average Metrics Across All Categories:
# ========================================
# <style type="text/css">
# #T_2d631_row0_col0, #T_2d631_row0_col1, #T_2d631_row0_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_2d631">
#   <caption>Average Metrics Across All Categories</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d631_level0_col0" class="col_heading level0 col0" >Avg Accuracy</th>
#       <th id="T_2d631_level0_col1" class="col_heading level0 col1" >Avg Precision</th>
#       <th id="T_2d631_level0_col2" class="col_heading level0 col2" >Avg Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d631_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d631_row0_col0" class="data row0 col0" >0.944</td>
#       <td id="T_2d631_row0_col1" class="data row0 col1" >0.929</td>
#       <td id="T_2d631_row0_col2" class="data row0 col2" >0.944</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
# Custom classifier for columns with only one class
class SingleClassPredictor(BaseEstimator, ClassifierMixin):
    def __init__(self, constant_value=0):
        self.constant_value = constant_value
        
    def fit(self, X, Y):
        self.constant_value = int(Y.iloc[0]) if hasattr(Y, 'iloc') else int(Y[0])
        return self
        
    def predict(self, X):
        return np.full(X.shape[0], self.constant_value)

# Custom tokenizer
def custom_tokenize(text):
    """Enhanced tokenizer with better text preprocessing"""
    # Handle URLs if present
    url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_pattern, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")
    
    # Clean text
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text.lower())
    
    # Tokenize
    tokens = re.findall(r'\b\w+\b', text)
    
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    clean_tokens = [lemmatizer.lemmatize(token).strip() for token in tokens if len(token) > 1]
    
    return clean_tokens

# Function to display comprehensive metrics for model evaluation
def display_model_metrics(Y_test, Y_pred, category_names):
    """
    Display comprehensive metrics for model evaluation
    
    Parameters:
    y_test - DataFrame with true labels
    y_pred - Array with predictions (can be 1D or 2D)
    category_names - List of category names
    """
    # Check dimensions of y_pred
    if len(Y_pred.shape) == 1:
        # If y_pred is 1D but evaluating multiple categories
        if len(category_names) > 1:
            print("Warning: y_pred is 1-dimensional but multiple categories provided.")
            print("Evaluating only the first category.")
            category_names = [category_names[0]]
            Y_test = Y_test.iloc[:, 0:1]
            # Reshape for consistent handling
            Y_pred = Y_pred.reshape(-1, 1)
    
    # Overall accuracy for each category
    accuracies = {}
    for idx, category in enumerate(category_names):
        accuracies[category] = accuracy_score(Y_test.iloc[:, idx], Y_pred[:, idx])
    
    # Create accuracy DataFrame
    acc_df = pd.DataFrame.from_dict(accuracies, orient='index', columns=['Accuracy'])
    print("\nOverall Accuracy for Each Category:")
    display(acc_df.style.background_gradient(cmap='YlOrBr')
           .format(precision=3)
           .set_caption('Model Accuracy by Category'))
    
    # Detailed metrics for each category
    print("\nDetailed Classification Metrics by Category:")
    for idx, category in enumerate(category_names):
        Y_true = Y_test.iloc[:, idx]
        Y_pred_cat = Y_pred[:, idx]  # Changed variable name to avoid conflict
        
        report = classification_report(Y_true, Y_pred_cat, output_dict=True, zero_division=0)
        df_report = pd.DataFrame(report).round(3)
        
        print(f'\n{"="*20}')
        print(f'Category: {category}')
        print(f'{"="*20}')
        
        styled_df = df_report.style\
            .background_gradient(cmap='YlOrBr')\
            .format(precision=3)\
            .set_table_styles([
                {'selector': 'th', 'props': [('background-color', '#eee'),
                                          ('color', '#000'),
                                          ('font-weight', 'bold')]},
                {'selector': '', 'props': [('border', '2px solid #333')]},
                {'selector': 'tbody td', 'props': [('border', '1px solid #666')]}
            ])
        
        display(styled_df)

# Fixed Gradient Boosting model
def build_fixed_gradient_boosting_model(X_train, X_test, Y_train, Y_test, category_names):
    """Build model with special handling for single-class columns and enhanced metrics"""
    
    # Create basic pipeline for feature extraction
    feature_pipeline = Pipeline([
        ('cvect', CountVectorizer(
            tokenizer=custom_tokenize,
            token_pattern=None,
            min_df=2,
            max_features=200
        )),
        ('tfidf', TfidfTransformer(use_idf=True))
    ])
    
    # Transform the features
    print("Extracting text features...")
    X_train_features = feature_pipeline.fit_transform(X_train)
    X_test_features = feature_pipeline.transform(X_test)
    
    # Train a separate classifier for each category
    print("Training individual classifiers for each category...")
    classifiers = {}
    Y_pred_all = np.zeros((X_test.shape[0], len(category_names)))
    
    for idx, category in enumerate(category_names):
        # Get target for this category
        Y_cat = Y_train.iloc[:, idx]
        
        # Check if this category has only one class
        unique_classes = Y_cat.unique()
        
        if len(unique_classes) == 1:
            print(f"Category '{category}' has only one class. Using constant predictor.")
            # Use a simple predictor that always returns the constant value
            clf = SingleClassPredictor(constant_value=unique_classes[0])
            clf.fit(X_train_features, Y_cat)
            Y_pred_all[:, idx] = clf.predict(X_test_features)
        else:
            print(f"Training GradientBoostingClassifier for '{category}'...")
            # Use GradientBoosting for categories with multiple classes
            clf = GradientBoostingClassifier(
                n_estimators=100,
                learning_rate=0.1,
                max_depth=3,
                subsample=0.8,
                random_state=42,
                verbose=0
            )
            clf.fit(X_train_features, Y_cat)
            Y_pred_all[:, idx] = clf.predict(X_test_features)
        
        classifiers[category] = clf
    
    # Model parameters
    print("\nModel Configuration:")
    print("=" * 40)
    print("Features: CountVectorizer with custom tokenizer + TF-IDF")
    print("Max Features:", feature_pipeline.named_steps['cvect'].max_features)
    print("Classifier: GradientBoostingClassifier (n_estimators=100, learning_rate=0.1, max_depth=3)")
    
    # Use the enhanced display_model_metrics function for evaluation
    print("\nModel Evaluation Metrics:")
    print("=" * 40)
    
    # Display detailed metrics using the new function
    display_model_metrics(Y_test, Y_pred_all, category_names)
    
    # Calculate average metrics across all categories
    print("\nAverage Metrics Across All Categories:")
    print("=" * 40)
    avg_metrics = {
        'Avg Accuracy': np.mean([accuracy_score(Y_test.iloc[:, i], Y_pred_all[:, i]) for i in range(len(category_names))]),
        'Avg Precision': np.mean([precision_score(Y_test.iloc[:, i], Y_pred_all[:, i], average='weighted', zero_division=0) 
                                for i in range(len(category_names))]),
        'Avg Recall': np.mean([recall_score(Y_test.iloc[:, i], Y_pred_all[:, i], average='weighted', zero_division=0) 
                              for i in range(len(category_names))]),
        'Avg F1 Score': np.mean([f1_score(Y_test.iloc[:, i], Y_pred_all[:, i], average='weighted', zero_division=0)
                               for i in range(len(category_names))])
    }
    
    avg_df = pd.DataFrame([avg_metrics])
    display(avg_df.style.format(precision=3)
           .background_gradient(cmap='YlOrBr')
           .set_caption('Average Metrics Across All Categories'))
    
    return classifiers, feature_pipeline

# %%
classifiers, feature_pipeline = build_fixed_gradient_boosting_model(X_train, X_test, Y_train, Y_test, category_names)
# Out:
# Extracting text features...
# Training individual classifiers for each category...
# Training GradientBoostingClassifier for 'related'...
# Training GradientBoostingClassifier for 'request'...
# Training GradientBoostingClassifier for 'offer'...
# Training GradientBoostingClassifier for 'aid_related'...
# Training GradientBoostingClassifier for 'medical_help'...
# Training GradientBoostingClassifier for 'medical_products'...
# Training GradientBoostingClassifier for 'search_and_rescue'...
# Training GradientBoostingClassifier for 'security'...
# Training GradientBoostingClassifier for 'military'...
# Category 'child_alone' has only one class. Using constant predictor.
# Training GradientBoostingClassifier for 'water'...
# Training GradientBoostingClassifier for 'food'...
# Training GradientBoostingClassifier for 'shelter'...
# Training GradientBoostingClassifier for 'clothing'...
# Training GradientBoostingClassifier for 'money'...
# Training GradientBoostingClassifier for 'missing_people'...
# Training GradientBoostingClassifier for 'refugees'...
# Training GradientBoostingClassifier for 'death'...
# Training GradientBoostingClassifier for 'other_aid'...
# Training GradientBoostingClassifier for 'infrastructure_related'...
# Training GradientBoostingClassifier for 'transport'...
# Training GradientBoostingClassifier for 'buildings'...
# Training GradientBoostingClassifier for 'electricity'...
# Training GradientBoostingClassifier for 'tools'...
# Training GradientBoostingClassifier for 'hospitals'...
# Training GradientBoostingClassifier for 'shops'...
# Training GradientBoostingClassifier for 'aid_centers'...
# Training GradientBoostingClassifier for 'other_infrastructure'...
# Training GradientBoostingClassifier for 'weather_related'...
# Training GradientBoostingClassifier for 'floods'...
# Training GradientBoostingClassifier for 'storm'...
# Training GradientBoostingClassifier for 'fire'...
# Training GradientBoostingClassifier for 'earthquake'...
# Training GradientBoostingClassifier for 'cold'...
# Training GradientBoostingClassifier for 'other_weather'...
# Training GradientBoostingClassifier for 'direct_report'...
#
# Model Configuration:
# ========================================
# Features: CountVectorizer with custom tokenizer + TF-IDF
# Max Features: 200
# Classifier: GradientBoostingClassifier (n_estimators=100, learning_rate=0.1, max_depth=3)
#
# Model Evaluation Metrics:
# ========================================
#
# Overall Accuracy for Each Category:
# <style type="text/css">
# #T_f6226_row0_col0 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_f6226_row1_col0 {
#   background-color: #f07818;
#   color: #f1f1f1;
# }
# #T_f6226_row2_col0 {
#   background-color: #702806;
#   color: #f1f1f1;
# }
# #T_f6226_row3_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f6226_row4_col0 {
#   background-color: #d95b09;
#   color: #f1f1f1;
# }
# #T_f6226_row5_col0 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_f6226_row6_col0, #T_f6226_row33_col0 {
#   background-color: #933204;
#   color: #f1f1f1;
# }
# #T_f6226_row7_col0, #T_f6226_row14_col0 {
#   background-color: #903104;
#   color: #f1f1f1;
# }
# #T_f6226_row8_col0 {
#   background-color: #9b3504;
#   color: #f1f1f1;
# }
# #T_f6226_row9_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_f6226_row10_col0, #T_f6226_row16_col0 {
#   background-color: #9c3604;
#   color: #f1f1f1;
# }
# #T_f6226_row11_col0 {
#   background-color: #b44103;
#   color: #f1f1f1;
# }
# #T_f6226_row12_col0 {
#   background-color: #b94303;
#   color: #f1f1f1;
# }
# #T_f6226_row13_col0, #T_f6226_row31_col0 {
#   background-color: #832d05;
#   color: #f1f1f1;
# }
# #T_f6226_row15_col0 {
#   background-color: #842e05;
#   color: #f1f1f1;
# }
# #T_f6226_row17_col0, #T_f6226_row27_col0 {
#   background-color: #ac3d03;
#   color: #f1f1f1;
# }
# #T_f6226_row18_col0 {
#   background-color: #fb9225;
#   color: #000000;
# }
# #T_f6226_row19_col0 {
#   background-color: #c94b02;
#   color: #f1f1f1;
# }
# #T_f6226_row20_col0 {
#   background-color: #a83b03;
#   color: #f1f1f1;
# }
# #T_f6226_row21_col0 {
#   background-color: #ab3c03;
#   color: #f1f1f1;
# }
# #T_f6226_row22_col0 {
#   background-color: #882f05;
#   color: #f1f1f1;
# }
# #T_f6226_row23_col0 {
#   background-color: #782a05;
#   color: #f1f1f1;
# }
# #T_f6226_row24_col0 {
#   background-color: #7b2b05;
#   color: #f1f1f1;
# }
# #T_f6226_row25_col0 {
#   background-color: #742905;
#   color: #f1f1f1;
# }
# #T_f6226_row26_col0 {
#   background-color: #812d05;
#   color: #f1f1f1;
# }
# #T_f6226_row28_col0 {
#   background-color: #feba46;
#   color: #000000;
# }
# #T_f6226_row29_col0 {
#   background-color: #bc4503;
#   color: #f1f1f1;
# }
# #T_f6226_row30_col0 {
#   background-color: #c14702;
#   color: #f1f1f1;
# }
# #T_f6226_row32_col0 {
#   background-color: #a63a03;
#   color: #f1f1f1;
# }
# #T_f6226_row34_col0 {
#   background-color: #b64203;
#   color: #f1f1f1;
# }
# #T_f6226_row35_col0 {
#   background-color: #fe9c2c;
#   color: #000000;
# }
# </style>
# <table id="T_f6226">
#   <caption>Model Accuracy by Category</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6226_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6226_level0_row0" class="row_heading level0 row0" >related</th>
#       <td id="T_f6226_row0_col0" class="data row0 col0" >0.799</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row1" class="row_heading level0 row1" >request</th>
#       <td id="T_f6226_row1_col0" class="data row1 col0" >0.895</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row2" class="row_heading level0 row2" >offer</th>
#       <td id="T_f6226_row2_col0" class="data row2 col0" >0.994</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row3" class="row_heading level0 row3" >aid_related</th>
#       <td id="T_f6226_row3_col0" class="data row3 col0" >0.737</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row4" class="row_heading level0 row4" >medical_help</th>
#       <td id="T_f6226_row4_col0" class="data row4 col0" >0.920</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row5" class="row_heading level0 row5" >medical_products</th>
#       <td id="T_f6226_row5_col0" class="data row5 col0" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row6" class="row_heading level0 row6" >search_and_rescue</th>
#       <td id="T_f6226_row6_col0" class="data row6 col0" >0.971</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row7" class="row_heading level0 row7" >security</th>
#       <td id="T_f6226_row7_col0" class="data row7 col0" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row8" class="row_heading level0 row8" >military</th>
#       <td id="T_f6226_row8_col0" class="data row8 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row9" class="row_heading level0 row9" >child_alone</th>
#       <td id="T_f6226_row9_col0" class="data row9 col0" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row10" class="row_heading level0 row10" >water</th>
#       <td id="T_f6226_row10_col0" class="data row10 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row11" class="row_heading level0 row11" >food</th>
#       <td id="T_f6226_row11_col0" class="data row11 col0" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row12" class="row_heading level0 row12" >shelter</th>
#       <td id="T_f6226_row12_col0" class="data row12 col0" >0.946</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row13" class="row_heading level0 row13" >clothing</th>
#       <td id="T_f6226_row13_col0" class="data row13 col0" >0.981</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row14" class="row_heading level0 row14" >money</th>
#       <td id="T_f6226_row14_col0" class="data row14 col0" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row15" class="row_heading level0 row15" >missing_people</th>
#       <td id="T_f6226_row15_col0" class="data row15 col0" >0.980</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row16" class="row_heading level0 row16" >refugees</th>
#       <td id="T_f6226_row16_col0" class="data row16 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row17" class="row_heading level0 row17" >death</th>
#       <td id="T_f6226_row17_col0" class="data row17 col0" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row18" class="row_heading level0 row18" >other_aid</th>
#       <td id="T_f6226_row18_col0" class="data row18 col0" >0.874</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row19" class="row_heading level0 row19" >infrastructure_related</th>
#       <td id="T_f6226_row19_col0" class="data row19 col0" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row20" class="row_heading level0 row20" >transport</th>
#       <td id="T_f6226_row20_col0" class="data row20 col0" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row21" class="row_heading level0 row21" >buildings</th>
#       <td id="T_f6226_row21_col0" class="data row21 col0" >0.955</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row22" class="row_heading level0 row22" >electricity</th>
#       <td id="T_f6226_row22_col0" class="data row22 col0" >0.978</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row23" class="row_heading level0 row23" >tools</th>
#       <td id="T_f6226_row23_col0" class="data row23 col0" >0.989</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row24" class="row_heading level0 row24" >hospitals</th>
#       <td id="T_f6226_row24_col0" class="data row24 col0" >0.986</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row25" class="row_heading level0 row25" >shops</th>
#       <td id="T_f6226_row25_col0" class="data row25 col0" >0.990</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row26" class="row_heading level0 row26" >aid_centers</th>
#       <td id="T_f6226_row26_col0" class="data row26 col0" >0.982</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row27" class="row_heading level0 row27" >other_infrastructure</th>
#       <td id="T_f6226_row27_col0" class="data row27 col0" >0.955</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row28" class="row_heading level0 row28" >weather_related</th>
#       <td id="T_f6226_row28_col0" class="data row28 col0" >0.843</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row29" class="row_heading level0 row29" >floods</th>
#       <td id="T_f6226_row29_col0" class="data row29 col0" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row30" class="row_heading level0 row30" >storm</th>
#       <td id="T_f6226_row30_col0" class="data row30 col0" >0.941</td>
#     </tr>
#     <tr>
#       <th id="T_f6226_level0_row31" class="row_h
# Detailed Classification Metrics by Category:
#
# ====================
# Category: related
# ====================
# <style type="text/css">
# #T_187b6 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_187b6  {
#   border: 2px solid #333;
# }
# #T_187b6 tbody td {
#   border: 1px solid #666;
# }
# #T_187b6_row0_col0, #T_187b6_row0_col1, #T_187b6_row0_col2, #T_187b6_row0_col3, #T_187b6_row0_col4, #T_187b6_row1_col0, #T_187b6_row1_col1, #T_187b6_row1_col2, #T_187b6_row1_col3, #T_187b6_row1_col4, #T_187b6_row2_col0, #T_187b6_row2_col1, #T_187b6_row2_col2, #T_187b6_row2_col3, #T_187b6_row2_col4, #T_187b6_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_187b6_row3_col0, #T_187b6_row3_col1, #T_187b6_row3_col3, #T_187b6_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_187b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_187b6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_187b6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_187b6_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_187b6_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_187b6_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_187b6_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_187b6_row0_col0" class="data row0 col0" >0.732</td>
#       <td id="T_187b6_row0_col1" class="data row0 col1" >0.805</td>
#       <td id="T_187b6_row0_col2" class="data row0 col2" >0.799</td>
#       <td id="T_187b6_row0_col3" class="data row0 col3" >0.768</td>
#       <td id="T_187b6_row0_col4" class="data row0 col4" >0.787</td>
#     </tr>
#     <tr>
#       <th id="T_187b6_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_187b6_row1_col0" class="data row1 col0" >0.242</td>
#       <td id="T_187b6_row1_col1" class="data row1 col1" >0.972</td>
#       <td id="T_187b6_row1_col2" class="data row1 col2" >0.799</td>
#       <td id="T_187b6_row1_col3" class="data row1 col3" >0.607</td>
#       <td id="T_187b6_row1_col4" class="data row1 col4" >0.799</td>
#     </tr>
#     <tr>
#       <th id="T_187b6_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_187b6_row2_col0" class="data row2 col0" >0.364</td>
#       <td id="T_187b6_row2_col1" class="data row2 col1" >0.881</td>
#       <td id="T_187b6_row2_col2" class="data row2 col2" >0.799</td>
#       <td id="T_187b6_row2_col3" class="data row2 col3" >0.622</td>
#       <td id="T_187b6_row2_col4" class="data row2 col4" >0.758</td>
#     </tr>
#     <tr>
#       <th id="T_187b6_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_187b6_row3_col0" class="data row3 col0" >1245.000</td>
#       <td id="T_187b6_row3_col1" class="data row3 col1" >3998.000</td>
#       <td id="T_187b6_row3_col2" class="data row3 col2" >0.799</td>
#       <td id="T_187b6_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_187b6_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: request
# ====================
# <style type="text/css">
# #T_e7750 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_e7750  {
#   border: 2px solid #333;
# }
# #T_e7750 tbody td {
#   border: 1px solid #666;
# }
# #T_e7750_row0_col0, #T_e7750_row0_col1, #T_e7750_row0_col2, #T_e7750_row0_col3, #T_e7750_row0_col4, #T_e7750_row1_col0, #T_e7750_row1_col1, #T_e7750_row1_col2, #T_e7750_row1_col3, #T_e7750_row1_col4, #T_e7750_row2_col0, #T_e7750_row2_col1, #T_e7750_row2_col2, #T_e7750_row2_col3, #T_e7750_row2_col4, #T_e7750_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e7750_row3_col0, #T_e7750_row3_col1, #T_e7750_row3_col3, #T_e7750_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7750">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7750_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e7750_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e7750_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_e7750_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_e7750_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7750_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_e7750_row0_col0" class="data row0 col0" >0.903</td>
#       <td id="T_e7750_row0_col1" class="data row0 col1" >0.823</td>
#       <td id="T_e7750_row0_col2" class="data row0 col2" >0.895</td>
#       <td id="T_e7750_row0_col3" class="data row0 col3" >0.863</td>
#       <td id="T_e7750_row0_col4" class="data row0 col4" >0.889</td>
#     </tr>
#     <tr>
#       <th id="T_e7750_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_e7750_row1_col0" class="data row1 col0" >0.979</td>
#       <td id="T_e7750_row1_col1" class="data row1 col1" >0.486</td>
#       <td id="T_e7750_row1_col2" class="data row1 col2" >0.895</td>
#       <td id="T_e7750_row1_col3" class="data row1 col3" >0.732</td>
#       <td id="T_e7750_row1_col4" class="data row1 col4" >0.895</td>
#     </tr>
#     <tr>
#       <th id="T_e7750_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_e7750_row2_col0" class="data row2 col0" >0.939</td>
#       <td id="T_e7750_row2_col1" class="data row2 col1" >0.611</td>
#       <td id="T_e7750_row2_col2" class="data row2 col2" >0.895</td>
#       <td id="T_e7750_row2_col3" class="data row2 col3" >0.775</td>
#       <td id="T_e7750_row2_col4" class="data row2 col4" >0.883</td>
#     </tr>
#     <tr>
#       <th id="T_e7750_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_e7750_row3_col0" class="data row3 col0" >4352.000</td>
#       <td id="T_e7750_row3_col1" class="data row3 col1" >891.000</td>
#       <td id="T_e7750_row3_col2" class="data row3 col2" >0.895</td>
#       <td id="T_e7750_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_e7750_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: offer
# ====================
# <style type="text/css">
# #T_1123b th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_1123b  {
#   border: 2px solid #333;
# }
# #T_1123b tbody td {
#   border: 1px solid #666;
# }
# #T_1123b_row0_col0, #T_1123b_row0_col1, #T_1123b_row0_col2, #T_1123b_row0_col3, #T_1123b_row0_col4, #T_1123b_row1_col0, #T_1123b_row1_col1, #T_1123b_row1_col2, #T_1123b_row1_col3, #T_1123b_row1_col4, #T_1123b_row2_col0, #T_1123b_row2_col1, #T_1123b_row2_col2, #T_1123b_row2_col3, #T_1123b_row2_col4, #T_1123b_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1123b_row3_col0, #T_1123b_row3_col1, #T_1123b_row3_col3, #T_1123b_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1123b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1123b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1123b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1123b_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_1123b_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_1123b_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1123b_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_1123b_row0_col0" class="data row0 col0" >0.995</td>
#       <td id="T_1123b_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_1123b_row0_col2" class="data row0 col2" >0.994</td>
#       <td id="T_1123b_row0_col3" class="data row0 col3" >0.498</td>
#       <td id="T_1123b_row0_col4" class="data row0 col4" >0.991</td>
#     </tr>
#     <tr>
#       <th id="T_1123b_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_1123b_row1_col0" class="data row1 col0" >0.998</td>
#       <td id="T_1123b_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_1123b_row1_col2" class="data row1 col2" >0.994</td>
#       <td id="T_1123b_row1_col3" class="data row1 col3" >0.499</td>
#       <td id="T_1123b_row1_col4" class="data row1 col4" >0.994</td>
#     </tr>
#     <tr>
#       <th id="T_1123b_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_1123b_row2_col0" class="data row2 col0" >0.997</td>
#       <td id="T_1123b_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_1123b_row2_col2" class="data row2 col2" >0.994</td>
#       <td id="T_1123b_row2_col3" class="data row2 col3" >0.498</td>
#       <td id="T_1123b_row2_col4" class="data row2 col4" >0.992</td>
#     </tr>
#     <tr>
#       <th id="T_1123b_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_1123b_row3_col0" class="data row3 col0" >5219.000</td>
#       <td id="T_1123b_row3_col1" class="data row3 col1" >24.000</td>
#       <td id="T_1123b_row3_col2" class="data row3 col2" >0.994</td>
#       <td id="T_1123b_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_1123b_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: aid_related
# ====================
# <style type="text/css">
# #T_cae1c th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_cae1c  {
#   border: 2px solid #333;
# }
# #T_cae1c tbody td {
#   border: 1px solid #666;
# }
# #T_cae1c_row0_col0, #T_cae1c_row0_col1, #T_cae1c_row0_col2, #T_cae1c_row0_col3, #T_cae1c_row0_col4, #T_cae1c_row1_col0, #T_cae1c_row1_col1, #T_cae1c_row1_col2, #T_cae1c_row1_col3, #T_cae1c_row1_col4, #T_cae1c_row2_col0, #T_cae1c_row2_col1, #T_cae1c_row2_col2, #T_cae1c_row2_col3, #T_cae1c_row2_col4, #T_cae1c_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_cae1c_row3_col0, #T_cae1c_row3_col1, #T_cae1c_row3_col3, #T_cae1c_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cae1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cae1c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cae1c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cae1c_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_cae1c_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_cae1c_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cae1c_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_cae1c_row0_col0" class="data row0 col0" >0.728</td>
#       <td id="T_cae1c_row0_col1" class="data row0 col1" >0.759</td>
#       <td id="T_cae1c_row0_col2" class="data row0 col2" >0.737</td>
#       <td id="T_cae1c_row0_col3" class="data row0 col3" >0.743</td>
#       <td id="T_cae1c_row0_col4" class="data row0 col4" >0.741</td>
#     </tr>
#     <tr>
#       <th id="T_cae1c_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_cae1c_row1_col0" class="data row1 col0" >0.881</td>
#       <td id="T_cae1c_row1_col1" class="data row1 col1" >0.531</td>
#       <td id="T_cae1c_row1_col2" class="data row1 col2" >0.737</td>
#       <td id="T_cae1c_row1_col3" class="data row1 col3" >0.706</td>
#       <td id="T_cae1c_row1_col4" class="data row1 col4" >0.737</td>
#     </tr>
#     <tr>
#       <th id="T_cae1c_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_cae1c_row2_col0" class="data row2 col0" >0.797</td>
#       <td id="T_cae1c_row2_col1" class="data row2 col1" >0.625</td>
#       <td id="T_cae1c_row2_col2" class="data row2 col2" >0.737</td>
#       <td id="T_cae1c_row2_col3" class="data row2 col3" >0.711</td>
#       <td id="T_cae1c_row2_col4" class="data row2 col4" >0.726</td>
#     </tr>
#     <tr>
#       <th id="T_cae1c_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_cae1c_row3_col0" class="data row3 col0" >3079.000</td>
#       <td id="T_cae1c_row3_col1" class="data row3 col1" >2164.000</td>
#       <td id="T_cae1c_row3_col2" class="data row3 col2" >0.737</td>
#       <td id="T_cae1c_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_cae1c_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: medical_help
# ====================
# <style type="text/css">
# #T_0757d th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_0757d  {
#   border: 2px solid #333;
# }
# #T_0757d tbody td {
#   border: 1px solid #666;
# }
# #T_0757d_row0_col0, #T_0757d_row0_col1, #T_0757d_row0_col2, #T_0757d_row0_col3, #T_0757d_row0_col4, #T_0757d_row1_col0, #T_0757d_row1_col1, #T_0757d_row1_col2, #T_0757d_row1_col3, #T_0757d_row1_col4, #T_0757d_row2_col0, #T_0757d_row2_col1, #T_0757d_row2_col2, #T_0757d_row2_col3, #T_0757d_row2_col4, #T_0757d_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_0757d_row3_col0, #T_0757d_row3_col1, #T_0757d_row3_col3, #T_0757d_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0757d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0757d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0757d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_0757d_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_0757d_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_0757d_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0757d_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_0757d_row0_col0" class="data row0 col0" >0.927</td>
#       <td id="T_0757d_row0_col1" class="data row0 col1" >0.579</td>
#       <td id="T_0757d_row0_col2" class="data row0 col2" >0.920</td>
#       <td id="T_0757d_row0_col3" class="data row0 col3" >0.753</td>
#       <td id="T_0757d_row0_col4" class="data row0 col4" >0.899</td>
#     </tr>
#     <tr>
#       <th id="T_0757d_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_0757d_row1_col0" class="data row1 col0" >0.991</td>
#       <td id="T_0757d_row1_col1" class="data row1 col1" >0.143</td>
#       <td id="T_0757d_row1_col2" class="data row1 col2" >0.920</td>
#       <td id="T_0757d_row1_col3" class="data row1 col3" >0.567</td>
#       <td id="T_0757d_row1_col4" class="data row1 col4" >0.920</td>
#     </tr>
#     <tr>
#       <th id="T_0757d_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_0757d_row2_col0" class="data row2 col0" >0.958</td>
#       <td id="T_0757d_row2_col1" class="data row2 col1" >0.229</td>
#       <td id="T_0757d_row2_col2" class="data row2 col2" >0.920</td>
#       <td id="T_0757d_row2_col3" class="data row2 col3" >0.593</td>
#       <td id="T_0757d_row2_col4" class="data row2 col4" >0.897</td>
#     </tr>
#     <tr>
#       <th id="T_0757d_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_0757d_row3_col0" class="data row3 col0" >4808.000</td>
#       <td id="T_0757d_row3_col1" class="data row3 col1" >435.000</td>
#       <td id="T_0757d_row3_col2" class="data row3 col2" >0.920</td>
#       <td id="T_0757d_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_0757d_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: medical_products
# ====================
# <style type="text/css">
# #T_1a284 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_1a284  {
#   border: 2px solid #333;
# }
# #T_1a284 tbody td {
#   border: 1px solid #666;
# }
# #T_1a284_row0_col0, #T_1a284_row0_col1, #T_1a284_row0_col2, #T_1a284_row0_col3, #T_1a284_row0_col4, #T_1a284_row1_col0, #T_1a284_row1_col1, #T_1a284_row1_col2, #T_1a284_row1_col3, #T_1a284_row1_col4, #T_1a284_row2_col0, #T_1a284_row2_col1, #T_1a284_row2_col2, #T_1a284_row2_col3, #T_1a284_row2_col4, #T_1a284_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1a284_row3_col0, #T_1a284_row3_col1, #T_1a284_row3_col3, #T_1a284_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a284">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a284_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1a284_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1a284_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_1a284_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_1a284_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a284_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_1a284_row0_col0" class="data row0 col0" >0.951</td>
#       <td id="T_1a284_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_1a284_row0_col2" class="data row0 col2" >0.947</td>
#       <td id="T_1a284_row0_col3" class="data row0 col3" >0.725</td>
#       <td id="T_1a284_row0_col4" class="data row0 col4" >0.927</td>
#     </tr>
#     <tr>
#       <th id="T_1a284_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_1a284_row1_col0" class="data row1 col0" >0.995</td>
#       <td id="T_1a284_row1_col1" class="data row1 col1" >0.082</td>
#       <td id="T_1a284_row1_col2" class="data row1 col2" >0.947</td>
#       <td id="T_1a284_row1_col3" class="data row1 col3" >0.539</td>
#       <td id="T_1a284_row1_col4" class="data row1 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_1a284_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_1a284_row2_col0" class="data row2 col0" >0.973</td>
#       <td id="T_1a284_row2_col1" class="data row2 col1" >0.142</td>
#       <td id="T_1a284_row2_col2" class="data row2 col2" >0.947</td>
#       <td id="T_1a284_row2_col3" class="data row2 col3" >0.557</td>
#       <td id="T_1a284_row2_col4" class="data row2 col4" >0.928</td>
#     </tr>
#     <tr>
#       <th id="T_1a284_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_1a284_row3_col0" class="data row3 col0" >4964.000</td>
#       <td id="T_1a284_row3_col1" class="data row3 col1" >279.000</td>
#       <td id="T_1a284_row3_col2" class="data row3 col2" >0.947</td>
#       <td id="T_1a284_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_1a284_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: search_and_rescue
# ====================
# <style type="text/css">
# #T_540d9 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_540d9  {
#   border: 2px solid #333;
# }
# #T_540d9 tbody td {
#   border: 1px solid #666;
# }
# #T_540d9_row0_col0, #T_540d9_row0_col1, #T_540d9_row0_col2, #T_540d9_row0_col3, #T_540d9_row0_col4, #T_540d9_row1_col0, #T_540d9_row1_col1, #T_540d9_row1_col2, #T_540d9_row1_col3, #T_540d9_row1_col4, #T_540d9_row2_col0, #T_540d9_row2_col1, #T_540d9_row2_col2, #T_540d9_row2_col3, #T_540d9_row2_col4, #T_540d9_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_540d9_row3_col0, #T_540d9_row3_col1, #T_540d9_row3_col3, #T_540d9_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_540d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_540d9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_540d9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_540d9_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_540d9_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_540d9_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_540d9_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_540d9_row0_col0" class="data row0 col0" >0.975</td>
#       <td id="T_540d9_row0_col1" class="data row0 col1" >0.130</td>
#       <td id="T_540d9_row0_col2" class="data row0 col2" >0.971</td>
#       <td id="T_540d9_row0_col3" class="data row0 col3" >0.552</td>
#       <td id="T_540d9_row0_col4" class="data row0 col4" >0.953</td>
#     </tr>
#     <tr>
#       <th id="T_540d9_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_540d9_row1_col0" class="data row1 col0" >0.996</td>
#       <td id="T_540d9_row1_col1" class="data row1 col1" >0.022</td>
#       <td id="T_540d9_row1_col2" class="data row1 col2" >0.971</td>
#       <td id="T_540d9_row1_col3" class="data row1 col3" >0.509</td>
#       <td id="T_540d9_row1_col4" class="data row1 col4" >0.971</td>
#     </tr>
#     <tr>
#       <th id="T_540d9_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_540d9_row2_col0" class="data row2 col0" >0.985</td>
#       <td id="T_540d9_row2_col1" class="data row2 col1" >0.038</td>
#       <td id="T_540d9_row2_col2" class="data row2 col2" >0.971</td>
#       <td id="T_540d9_row2_col3" class="data row2 col3" >0.511</td>
#       <td id="T_540d9_row2_col4" class="data row2 col4" >0.961</td>
#     </tr>
#     <tr>
#       <th id="T_540d9_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_540d9_row3_col0" class="data row3 col0" >5107.000</td>
#       <td id="T_540d9_row3_col1" class="data row3 col1" >136.000</td>
#       <td id="T_540d9_row3_col2" class="data row3 col2" >0.971</td>
#       <td id="T_540d9_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_540d9_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: security
# ====================
# <style type="text/css">
# #T_6bcce th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_6bcce  {
#   border: 2px solid #333;
# }
# #T_6bcce tbody td {
#   border: 1px solid #666;
# }
# #T_6bcce_row0_col0, #T_6bcce_row0_col1, #T_6bcce_row0_col2, #T_6bcce_row0_col3, #T_6bcce_row0_col4, #T_6bcce_row1_col0, #T_6bcce_row1_col1, #T_6bcce_row1_col2, #T_6bcce_row1_col3, #T_6bcce_row1_col4, #T_6bcce_row2_col0, #T_6bcce_row2_col1, #T_6bcce_row2_col2, #T_6bcce_row2_col3, #T_6bcce_row2_col4, #T_6bcce_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6bcce_row3_col0, #T_6bcce_row3_col1, #T_6bcce_row3_col3, #T_6bcce_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6bcce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bcce_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6bcce_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6bcce_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_6bcce_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_6bcce_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bcce_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_6bcce_row0_col0" class="data row0 col0" >0.982</td>
#       <td id="T_6bcce_row0_col1" class="data row0 col1" >0.056</td>
#       <td id="T_6bcce_row0_col2" class="data row0 col2" >0.973</td>
#       <td id="T_6bcce_row0_col3" class="data row0 col3" >0.519</td>
#       <td id="T_6bcce_row0_col4" class="data row0 col4" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_6bcce_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_6bcce_row1_col0" class="data row1 col0" >0.990</td>
#       <td id="T_6bcce_row1_col1" class="data row1 col1" >0.031</td>
#       <td id="T_6bcce_row1_col2" class="data row1 col2" >0.973</td>
#       <td id="T_6bcce_row1_col3" class="data row1 col3" >0.511</td>
#       <td id="T_6bcce_row1_col4" class="data row1 col4" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_6bcce_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_6bcce_row2_col0" class="data row2 col0" >0.986</td>
#       <td id="T_6bcce_row2_col1" class="data row2 col1" >0.040</td>
#       <td id="T_6bcce_row2_col2" class="data row2 col2" >0.973</td>
#       <td id="T_6bcce_row2_col3" class="data row2 col3" >0.513</td>
#       <td id="T_6bcce_row2_col4" class="data row2 col4" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_6bcce_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_6bcce_row3_col0" class="data row3 col0" >5147.000</td>
#       <td id="T_6bcce_row3_col1" class="data row3 col1" >96.000</td>
#       <td id="T_6bcce_row3_col2" class="data row3 col2" >0.973</td>
#       <td id="T_6bcce_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_6bcce_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: military
# ====================
# <style type="text/css">
# #T_feff5 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_feff5  {
#   border: 2px solid #333;
# }
# #T_feff5 tbody td {
#   border: 1px solid #666;
# }
# #T_feff5_row0_col0, #T_feff5_row0_col1, #T_feff5_row0_col2, #T_feff5_row0_col3, #T_feff5_row0_col4, #T_feff5_row1_col0, #T_feff5_row1_col1, #T_feff5_row1_col2, #T_feff5_row1_col3, #T_feff5_row1_col4, #T_feff5_row2_col0, #T_feff5_row2_col1, #T_feff5_row2_col2, #T_feff5_row2_col3, #T_feff5_row2_col4, #T_feff5_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_feff5_row3_col0, #T_feff5_row3_col1, #T_feff5_row3_col3, #T_feff5_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_feff5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_feff5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_feff5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_feff5_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_feff5_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_feff5_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feff5_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_feff5_row0_col0" class="data row0 col0" >0.970</td>
#       <td id="T_feff5_row0_col1" class="data row0 col1" >0.077</td>
#       <td id="T_feff5_row0_col2" class="data row0 col2" >0.966</td>
#       <td id="T_feff5_row0_col3" class="data row0 col3" >0.524</td>
#       <td id="T_feff5_row0_col4" class="data row0 col4" >0.943</td>
#     </tr>
#     <tr>
#       <th id="T_feff5_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_feff5_row1_col0" class="data row1 col0" >0.995</td>
#       <td id="T_feff5_row1_col1" class="data row1 col1" >0.013</td>
#       <td id="T_feff5_row1_col2" class="data row1 col2" >0.966</td>
#       <td id="T_feff5_row1_col3" class="data row1 col3" >0.504</td>
#       <td id="T_feff5_row1_col4" class="data row1 col4" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_feff5_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_feff5_row2_col0" class="data row2 col0" >0.983</td>
#       <td id="T_feff5_row2_col1" class="data row2 col1" >0.022</td>
#       <td id="T_feff5_row2_col2" class="data row2 col2" >0.966</td>
#       <td id="T_feff5_row2_col3" class="data row2 col3" >0.502</td>
#       <td id="T_feff5_row2_col4" class="data row2 col4" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_feff5_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_feff5_row3_col0" class="data row3 col0" >5085.000</td>
#       <td id="T_feff5_row3_col1" class="data row3 col1" >158.000</td>
#       <td id="T_feff5_row3_col2" class="data row3 col2" >0.966</td>
#       <td id="T_feff5_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_feff5_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: child_alone
# ====================
# <style type="text/css">
# #T_6fb0c th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_6fb0c  {
#   border: 2px solid #333;
# }
# #T_6fb0c tbody td {
#   border: 1px solid #666;
# }
# #T_6fb0c_row0_col0, #T_6fb0c_row0_col1, #T_6fb0c_row0_col2, #T_6fb0c_row0_col3, #T_6fb0c_row1_col0, #T_6fb0c_row1_col1, #T_6fb0c_row1_col2, #T_6fb0c_row1_col3, #T_6fb0c_row2_col0, #T_6fb0c_row2_col1, #T_6fb0c_row2_col2, #T_6fb0c_row2_col3, #T_6fb0c_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6fb0c_row3_col0, #T_6fb0c_row3_col2, #T_6fb0c_row3_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6fb0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fb0c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6fb0c_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_6fb0c_level0_col2" class="col_heading level0 col2" >macro avg</th>
#       <th id="T_6fb0c_level0_col3" class="col_heading level0 col3" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fb0c_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_6fb0c_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_6fb0c_row0_col1" class="data row0 col1" >1.000</td>
#       <td id="T_6fb0c_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_6fb0c_row0_col3" class="data row0 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_6fb0c_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_6fb0c_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_6fb0c_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_6fb0c_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_6fb0c_row1_col3" class="data row1 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_6fb0c_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_6fb0c_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_6fb0c_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_6fb0c_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_6fb0c_row2_col3" class="data row2 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_6fb0c_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_6fb0c_row3_col0" class="data row3 col0" >5243.000</td>
#       <td id="T_6fb0c_row3_col1" class="data row3 col1" >1.000</td>
#       <td id="T_6fb0c_row3_col2" class="data row3 col2" >5243.000</td>
#       <td id="T_6fb0c_row3_col3" class="data row3 col3" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: water
# ====================
# <style type="text/css">
# #T_f5735 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_f5735  {
#   border: 2px solid #333;
# }
# #T_f5735 tbody td {
#   border: 1px solid #666;
# }
# #T_f5735_row0_col0, #T_f5735_row0_col1, #T_f5735_row0_col2, #T_f5735_row0_col3, #T_f5735_row0_col4, #T_f5735_row1_col0, #T_f5735_row1_col1, #T_f5735_row1_col2, #T_f5735_row1_col3, #T_f5735_row1_col4, #T_f5735_row2_col0, #T_f5735_row2_col1, #T_f5735_row2_col2, #T_f5735_row2_col3, #T_f5735_row2_col4, #T_f5735_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f5735_row3_col0, #T_f5735_row3_col1, #T_f5735_row3_col3, #T_f5735_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f5735">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5735_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f5735_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f5735_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_f5735_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_f5735_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5735_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_f5735_row0_col0" class="data row0 col0" >0.974</td>
#       <td id="T_f5735_row0_col1" class="data row0 col1" >0.782</td>
#       <td id="T_f5735_row0_col2" class="data row0 col2" >0.965</td>
#       <td id="T_f5735_row0_col3" class="data row0 col3" >0.878</td>
#       <td id="T_f5735_row0_col4" class="data row0 col4" >0.962</td>
#     </tr>
#     <tr>
#       <th id="T_f5735_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_f5735_row1_col0" class="data row1 col0" >0.988</td>
#       <td id="T_f5735_row1_col1" class="data row1 col1" >0.621</td>
#       <td id="T_f5735_row1_col2" class="data row1 col2" >0.965</td>
#       <td id="T_f5735_row1_col3" class="data row1 col3" >0.805</td>
#       <td id="T_f5735_row1_col4" class="data row1 col4" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_f5735_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_f5735_row2_col0" class="data row2 col0" >0.981</td>
#       <td id="T_f5735_row2_col1" class="data row2 col1" >0.692</td>
#       <td id="T_f5735_row2_col2" class="data row2 col2" >0.965</td>
#       <td id="T_f5735_row2_col3" class="data row2 col3" >0.837</td>
#       <td id="T_f5735_row2_col4" class="data row2 col4" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_f5735_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_f5735_row3_col0" class="data row3 col0" >4908.000</td>
#       <td id="T_f5735_row3_col1" class="data row3 col1" >335.000</td>
#       <td id="T_f5735_row3_col2" class="data row3 col2" >0.965</td>
#       <td id="T_f5735_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_f5735_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: food
# ====================
# <style type="text/css">
# #T_4c700 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_4c700  {
#   border: 2px solid #333;
# }
# #T_4c700 tbody td {
#   border: 1px solid #666;
# }
# #T_4c700_row0_col0, #T_4c700_row0_col1, #T_4c700_row0_col2, #T_4c700_row0_col3, #T_4c700_row0_col4, #T_4c700_row1_col0, #T_4c700_row1_col1, #T_4c700_row1_col2, #T_4c700_row1_col3, #T_4c700_row1_col4, #T_4c700_row2_col0, #T_4c700_row2_col1, #T_4c700_row2_col2, #T_4c700_row2_col3, #T_4c700_row2_col4, #T_4c700_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4c700_row3_col0, #T_4c700_row3_col1, #T_4c700_row3_col3, #T_4c700_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c700">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c700_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4c700_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4c700_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_4c700_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_4c700_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c700_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_4c700_row0_col0" class="data row0 col0" >0.964</td>
#       <td id="T_4c700_row0_col1" class="data row0 col1" >0.809</td>
#       <td id="T_4c700_row0_col2" class="data row0 col2" >0.949</td>
#       <td id="T_4c700_row0_col3" class="data row0 col3" >0.886</td>
#       <td id="T_4c700_row0_col4" class="data row0 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_4c700_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_4c700_row1_col0" class="data row1 col0" >0.979</td>
#       <td id="T_4c700_row1_col1" class="data row1 col1" >0.709</td>
#       <td id="T_4c700_row1_col2" class="data row1 col2" >0.949</td>
#       <td id="T_4c700_row1_col3" class="data row1 col3" >0.844</td>
#       <td id="T_4c700_row1_col4" class="data row1 col4" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_4c700_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_4c700_row2_col0" class="data row2 col0" >0.971</td>
#       <td id="T_4c700_row2_col1" class="data row2 col1" >0.755</td>
#       <td id="T_4c700_row2_col2" class="data row2 col2" >0.949</td>
#       <td id="T_4c700_row2_col3" class="data row2 col3" >0.863</td>
#       <td id="T_4c700_row2_col4" class="data row2 col4" >0.947</td>
#     </tr>
#     <tr>
#       <th id="T_4c700_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_4c700_row3_col0" class="data row3 col0" >4659.000</td>
#       <td id="T_4c700_row3_col1" class="data row3 col1" >584.000</td>
#       <td id="T_4c700_row3_col2" class="data row3 col2" >0.949</td>
#       <td id="T_4c700_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_4c700_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: shelter
# ====================
# <style type="text/css">
# #T_68be1 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_68be1  {
#   border: 2px solid #333;
# }
# #T_68be1 tbody td {
#   border: 1px solid #666;
# }
# #T_68be1_row0_col0, #T_68be1_row0_col1, #T_68be1_row0_col2, #T_68be1_row0_col3, #T_68be1_row0_col4, #T_68be1_row1_col0, #T_68be1_row1_col1, #T_68be1_row1_col2, #T_68be1_row1_col3, #T_68be1_row1_col4, #T_68be1_row2_col0, #T_68be1_row2_col1, #T_68be1_row2_col2, #T_68be1_row2_col3, #T_68be1_row2_col4, #T_68be1_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_68be1_row3_col0, #T_68be1_row3_col1, #T_68be1_row3_col3, #T_68be1_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68be1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68be1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_68be1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_68be1_level0_col2" class="col_heading level0 col2" >accuracy</th>
# ...
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_74a6b_row3_col0, #T_74a6b_row3_col1, #T_74a6b_row3_col3, #T_74a6b_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74a6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74a6b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_74a6b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_74a6b_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_74a6b_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_74a6b_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74a6b_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_74a6b_row0_col0" class="data row0 col0" >0.990</td>
#       <td id="T_74a6b_row0_col1" class="data row0 col1" >0.041</td>
#       <td id="T_74a6b_row0_col2" class="data row0 col2" >0.981</td>
#       <td id="T_74a6b_row0_col3" class="data row0 col3" >0.515</td>
#       <td id="T_74a6b_row0_col4" class="data row0 col4" >0.981</td>
#     </tr>
#     <tr>
#       <th id="T_74a6b_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_74a6b_row1_col0" class="data row1 col0" >0.991</td>
#       <td id="T_74a6b_row1_col1" class="data row1 col1" >0.038</td>
#       <td id="T_74a6b_row1_col2" class="data row1 col2" >0.981</td>
#       <td id="T_74a6b_row1_col3" class="data row1 col3" >0.514</td>
#       <td id="T_74a6b_row1_col4" class="data row1 col4" >0.981</td>
#     </tr>
#     <tr>
#       <th id="T_74a6b_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_74a6b_row2_col0" class="data row2 col0" >0.991</td>
#       <td id="T_74a6b_row2_col1" class="data row2 col1" >0.039</td>
#       <td id="T_74a6b_row2_col2" class="data row2 col2" >0.981</td>
#       <td id="T_74a6b_row2_col3" class="data row2 col3" >0.515</td>
#       <td id="T_74a6b_row2_col4" class="data row2 col4" >0.981</td>
#     </tr>
#     <tr>
#       <th id="T_74a6b_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_74a6b_row3_col0" class="data row3 col0" >5190.000</td>
#       <td id="T_74a6b_row3_col1" class="data row3 col1" >53.000</td>
#       <td id="T_74a6b_row3_col2" class="data row3 col2" >0.981</td>
#       <td id="T_74a6b_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_74a6b_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: earthquake
# ====================
# <style type="text/css">
# #T_a3a67 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_a3a67  {
#   border: 2px solid #333;
# }
# #T_a3a67 tbody td {
#   border: 1px solid #666;
# }
# #T_a3a67_row0_col0, #T_a3a67_row0_col1, #T_a3a67_row0_col2, #T_a3a67_row0_col3, #T_a3a67_row0_col4, #T_a3a67_row1_col0, #T_a3a67_row1_col1, #T_a3a67_row1_col2, #T_a3a67_row1_col3, #T_a3a67_row1_col4, #T_a3a67_row2_col0, #T_a3a67_row2_col1, #T_a3a67_row2_col2, #T_a3a67_row2_col3, #T_a3a67_row2_col4, #T_a3a67_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a3a67_row3_col0, #T_a3a67_row3_col1, #T_a3a67_row3_col3, #T_a3a67_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3a67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3a67_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a3a67_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a3a67_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_a3a67_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_a3a67_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3a67_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_a3a67_row0_col0" class="data row0 col0" >0.965</td>
#       <td id="T_a3a67_row0_col1" class="data row0 col1" >0.880</td>
#       <td id="T_a3a67_row0_col2" class="data row0 col2" >0.959</td>
#       <td id="T_a3a67_row0_col3" class="data row0 col3" >0.923</td>
#       <td id="T_a3a67_row0_col4" class="data row0 col4" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_a3a67_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_a3a67_row1_col0" class="data row1 col0" >0.990</td>
#       <td id="T_a3a67_row1_col1" class="data row1 col1" >0.670</td>
#       <td id="T_a3a67_row1_col2" class="data row1 col2" >0.959</td>
#       <td id="T_a3a67_row1_col3" class="data row1 col3" >0.830</td>
#       <td id="T_a3a67_row1_col4" class="data row1 col4" >0.959</td>
#     </tr>
#     <tr>
#       <th id="T_a3a67_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_a3a67_row2_col0" class="data row2 col0" >0.977</td>
#       <td id="T_a3a67_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_a3a67_row2_col2" class="data row2 col2" >0.959</td>
#       <td id="T_a3a67_row2_col3" class="data row2 col3" >0.869</td>
#       <td id="T_a3a67_row2_col4" class="data row2 col4" >0.956</td>
#     </tr>
#     <tr>
#       <th id="T_a3a67_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_a3a67_row3_col0" class="data row3 col0" >4728.000</td>
#       <td id="T_a3a67_row3_col1" class="data row3 col1" >515.000</td>
#       <td id="T_a3a67_row3_col2" class="data row3 col2" >0.959</td>
#       <td id="T_a3a67_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_a3a67_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: cold
# ====================
# <style type="text/css">
# #T_92729 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_92729  {
#   border: 2px solid #333;
# }
# #T_92729 tbody td {
#   border: 1px solid #666;
# }
# #T_92729_row0_col0, #T_92729_row0_col1, #T_92729_row0_col2, #T_92729_row0_col3, #T_92729_row0_col4, #T_92729_row1_col0, #T_92729_row1_col1, #T_92729_row1_col2, #T_92729_row1_col3, #T_92729_row1_col4, #T_92729_row2_col0, #T_92729_row2_col1, #T_92729_row2_col2, #T_92729_row2_col3, #T_92729_row2_col4, #T_92729_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_92729_row3_col0, #T_92729_row3_col1, #T_92729_row3_col3, #T_92729_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92729">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92729_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_92729_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_92729_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_92729_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_92729_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92729_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_92729_row0_col0" class="data row0 col0" >0.981</td>
#       <td id="T_92729_row0_col1" class="data row0 col1" >0.070</td>
#       <td id="T_92729_row0_col2" class="data row0 col2" >0.971</td>
#       <td id="T_92729_row0_col3" class="data row0 col3" >0.525</td>
#       <td id="T_92729_row0_col4" class="data row0 col4" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_92729_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_92729_row1_col0" class="data row1 col0" >0.990</td>
#       <td id="T_92729_row1_col1" class="data row1 col1" >0.038</td>
#       <td id="T_92729_row1_col2" class="data row1 col2" >0.971</td>
#       <td id="T_92729_row1_col3" class="data row1 col3" >0.514</td>
#       <td id="T_92729_row1_col4" class="data row1 col4" >0.971</td>
#     </tr>
#     <tr>
#       <th id="T_92729_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_92729_row2_col0" class="data row2 col0" >0.985</td>
#       <td id="T_92729_row2_col1" class="data row2 col1" >0.050</td>
#       <td id="T_92729_row2_col2" class="data row2 col2" >0.971</td>
#       <td id="T_92729_row2_col3" class="data row2 col3" >0.517</td>
#       <td id="T_92729_row2_col4" class="data row2 col4" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_92729_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_92729_row3_col0" class="data row3 col0" >5139.000</td>
#       <td id="T_92729_row3_col1" class="data row3 col1" >104.000</td>
#       <td id="T_92729_row3_col2" class="data row3 col2" >0.971</td>
#       <td id="T_92729_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_92729_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: other_weather
# ====================
# <style type="text/css">
# #T_7cff8 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_7cff8  {
#   border: 2px solid #333;
# }
# #T_7cff8 tbody td {
#   border: 1px solid #666;
# }
# #T_7cff8_row0_col0, #T_7cff8_row0_col1, #T_7cff8_row0_col2, #T_7cff8_row0_col3, #T_7cff8_row0_col4, #T_7cff8_row1_col0, #T_7cff8_row1_col1, #T_7cff8_row1_col2, #T_7cff8_row1_col3, #T_7cff8_row1_col4, #T_7cff8_row2_col0, #T_7cff8_row2_col1, #T_7cff8_row2_col2, #T_7cff8_row2_col3, #T_7cff8_row2_col4, #T_7cff8_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_7cff8_row3_col0, #T_7cff8_row3_col1, #T_7cff8_row3_col3, #T_7cff8_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7cff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cff8_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7cff8_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7cff8_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_7cff8_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_7cff8_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cff8_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_7cff8_row0_col0" class="data row0 col0" >0.950</td>
#       <td id="T_7cff8_row0_col1" class="data row0 col1" >0.312</td>
#       <td id="T_7cff8_row0_col2" class="data row0 col2" >0.948</td>
#       <td id="T_7cff8_row0_col3" class="data row0 col3" >0.631</td>
#       <td id="T_7cff8_row0_col4" class="data row0 col4" >0.917</td>
#     </tr>
#     <tr>
#       <th id="T_7cff8_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_7cff8_row1_col0" class="data row1 col0" >0.998</td>
#       <td id="T_7cff8_row1_col1" class="data row1 col1" >0.019</td>
#       <td id="T_7cff8_row1_col2" class="data row1 col2" >0.948</td>
#       <td id="T_7cff8_row1_col3" class="data row1 col3" >0.508</td>
#       <td id="T_7cff8_row1_col4" class="data row1 col4" >0.948</td>
#     </tr>
#     <tr>
#       <th id="T_7cff8_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_7cff8_row2_col0" class="data row2 col0" >0.973</td>
#       <td id="T_7cff8_row2_col1" class="data row2 col1" >0.035</td>
#       <td id="T_7cff8_row2_col2" class="data row2 col2" >0.948</td>
#       <td id="T_7cff8_row2_col3" class="data row2 col3" >0.504</td>
#       <td id="T_7cff8_row2_col4" class="data row2 col4" >0.925</td>
#     </tr>
#     <tr>
#       <th id="T_7cff8_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_7cff8_row3_col0" class="data row3 col0" >4976.000</td>
#       <td id="T_7cff8_row3_col1" class="data row3 col1" >267.000</td>
#       <td id="T_7cff8_row3_col2" class="data row3 col2" >0.948</td>
#       <td id="T_7cff8_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_7cff8_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# ====================
# Category: direct_report
# ====================
# <style type="text/css">
# #T_a71a2 th {
#   background-color: #eee;
#   color: #000;
#   font-weight: bold;
# }
# #T_a71a2  {
#   border: 2px solid #333;
# }
# #T_a71a2 tbody td {
#   border: 1px solid #666;
# }
# #T_a71a2_row0_col0, #T_a71a2_row0_col1, #T_a71a2_row0_col2, #T_a71a2_row0_col3, #T_a71a2_row0_col4, #T_a71a2_row1_col0, #T_a71a2_row1_col1, #T_a71a2_row1_col2, #T_a71a2_row1_col3, #T_a71a2_row1_col4, #T_a71a2_row2_col0, #T_a71a2_row2_col1, #T_a71a2_row2_col2, #T_a71a2_row2_col3, #T_a71a2_row2_col4, #T_a71a2_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a71a2_row3_col0, #T_a71a2_row3_col1, #T_a71a2_row3_col3, #T_a71a2_row3_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a71a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a71a2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a71a2_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a71a2_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_a71a2_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_a71a2_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a71a2_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_a71a2_row0_col0" class="data row0 col0" >0.874</td>
#       <td id="T_a71a2_row0_col1" class="data row0 col1" >0.788</td>
#       <td id="T_a71a2_row0_col2" class="data row0 col2" >0.866</td>
#       <td id="T_a71a2_row0_col3" class="data row0 col3" >0.831</td>
#       <td id="T_a71a2_row0_col4" class="data row0 col4" >0.858</td>
#     </tr>
#     <tr>
#       <th id="T_a71a2_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_a71a2_row1_col0" class="data row1 col0" >0.974</td>
#       <td id="T_a71a2_row1_col1" class="data row1 col1" >0.413</td>
#       <td id="T_a71a2_row1_col2" class="data row1 col2" >0.866</td>
#       <td id="T_a71a2_row1_col3" class="data row1 col3" >0.693</td>
#       <td id="T_a71a2_row1_col4" class="data row1 col4" >0.866</td>
#     </tr>
#     <tr>
#       <th id="T_a71a2_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_a71a2_row2_col0" class="data row2 col0" >0.921</td>
#       <td id="T_a71a2_row2_col1" class="data row2 col1" >0.542</td>
#       <td id="T_a71a2_row2_col2" class="data row2 col2" >0.866</td>
#       <td id="T_a71a2_row2_col3" class="data row2 col3" >0.732</td>
#       <td id="T_a71a2_row2_col4" class="data row2 col4" >0.848</td>
#     </tr>
#     <tr>
#       <th id="T_a71a2_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_a71a2_row3_col0" class="data row3 col0" >4233.000</td>
#       <td id="T_a71a2_row3_col1" class="data row3 col1" >1010.000</td>
#       <td id="T_a71a2_row3_col2" class="data row3 col2" >0.866</td>
#       <td id="T_a71a2_row3_col3" class="data row3 col3" >5243.000</td>
#       <td id="T_a71a2_row3_col4" class="data row3 col4" >5243.000</td>
#     </tr>
#   </tbody>
# </table>
# Average Metrics Across All Categories:
# ========================================
# <style type="text/css">
# #T_dc7a3_row0_col0, #T_dc7a3_row0_col1, #T_dc7a3_row0_col2, #T_dc7a3_row0_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_dc7a3">
#   <caption>Average Metrics Across All Categories</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc7a3_level0_col0" class="col_heading level0 col0" >Avg Accuracy</th>
#       <th id="T_dc7a3_level0_col1" class="col_heading level0 col1" >Avg Precision</th>
#       <th id="T_dc7a3_level0_col2" class="col_heading level0 col2" >Avg Recall</th>
#       <th id="T_dc7a3_level0_col3" class="col_heading level0 col3" >Avg F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc7a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc7a3_row0_col0" class="data row0 col0" >0.944</td>
#       <td id="T_dc7a3_row0_col1" class="data row0 col1" >0.934</td>
#       <td id="T_dc7a3_row0_col2" class="data row0 col2" >0.944</td>
#       <td id="T_dc7a3_row0_col3" class="data row0 col3" >0.933</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
# Get the current working directory
current_dir = os.getcwd()

# Construct the path to the models folder
# Navigate up one directory to the project root, then into models folder
model_path = os.path.join(current_dir, '..', 'models', 'classifier.pkl')

model_data = {
    'classifiers': classifiers,
    'feature_pipeline': feature_pipeline
}

# Ensure the directory exists
os.makedirs(os.path.dirname(model_path), exist_ok=True)

# Save the pickle file to the specified path
with open(model_path, 'wb') as f:
    pickle.dump(model_data, f)

# %%
# Get the current working directory
current_dir = os.getcwd()

# Construct the path to the models folder
# Navigate up one directory to the project root, then into models folder
model_path = os.path.join(current_dir, '..', 'models', 'classifier.pkl')

# Test loading the model
print("Loading model...")
with open(model_path, 'rb') as f:
    model_data = pickle.load(f)
    classifiers = model_data['classifiers']
    feature_pipeline = model_data['feature_pipeline']

# Get list of categories from the classifiers dictionary
categories = list(classifiers.keys())
print(f"Model loaded successfully with {len(categories)} categories: {categories}")
# Out:
# Loading model...
# Model loaded successfully with 36 categories: ['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']

# %% [markdown]
# ### 10. Use this notebook to complete `train_classifier.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.

# %%
#Export Python Notebook to html
# !jupyter nbconvert --to html "ML_Pipeline_Preparation.ipynb"
# Out:
# [NbConvertApp] Converting notebook ML_Pipeline_Preparation.ipynb to html
# [NbConvertApp] Writing 792299 bytes to ML_Pipeline_Preparation.html
